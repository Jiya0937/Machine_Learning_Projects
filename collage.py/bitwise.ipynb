# %%
# ex-or : when both valur are different than output will be 1 (like 0,1==1),and if both valur is same than output become 0(like 1 and 1==0 and 0,0=0)
s=2^4
s
"""
2=10 and 4=100 is binary off this so 
010
100
----
420
anwere=6 because order is 4,2,1
"""
# Out:
# 6

# %%
#left sift : sift left side according to given no and at the place of blank space 0 is filled
g=10>>2
g
# Out:
# 2

# %%
#right sift
j=10>>2
j
# Out:
# 2

# %%
#right sift : space print on left side and on this place 0 is create like 10/2
j=-10>>2
j
# Out:
# -3

# %%
#in python increment decrement not allowed
'''e=15
print(e++)'''
# Out:
# 'e=15\nprint(e++)'

# %%
# ternary operator
# a>b?a:b in c++
# a if a>b else b in python
a,b=9,10
a if a>b else b
# Out:
# 10

# %%
#nested ternary operator
a if a>b else(b if b>20 else print("not greater than 20"))
# Out:
# not greater than 20

# %%
# Identity operator(a is b)means if a==b so true else false
print(a is b)
print(a is not b)
# Out:
# False
# True

# %%
print("jiya deshmukh".title())
print("jiya deshmukh".upper())
print("DRASHTI SONI".lower())
# Out:
# Jiya Deshmukh
# JIYA DESHMUKH
# drashti soni

# %%
#membership operator

lists=[4,5,"jiya",76]
name="jiya deshmukh"

print(4 in lists)
print('jiya' in name)
print("JIYA" in name)
# Out:
# True
# True
# False

# %%
# give multiple input at same time
# list comprehension
a,b,c=[int(x) for x in input("enter 3 no : ").split()]
print(a+b+c)
# Out:
# enter 3 no :  8 2 2
# 12

# %%
p,q,r=[int(y) for y in input("enter 3 number").split()]
print(p*q*r)
# Out:
# enter 3 number 2 3 4
# 24

# %%
a,b=input("enter name").split()
print(a+b)
# Out:
# enter name jiya deshmukh
# jiyadeshmukh

# %%
p,q,r=[float(y) for y in input("enter 3 number").split()]
print(p*q*r)
# Out:
# enter 3 number 1.3 3.4 55.6
# 245.752

# %%
# eval() : take string as argument and evaluate to curresponding provided type
# eval understand the type of the input and run according to this type 
x=eval("10+20+30")
print(x)
# Out:
# 60

# %%
x=eval(input("enter any number"))
print(type(x))
# Out:
# enter any number 8
# <class 'int'>

# %%
p=[eval(x) for x in input("enter info").split()]
print(p)
for i in range(len(p)):
    print(type(p[i]))
# Out:
# enter info jiya jkii 9 8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[64], line 1
# ----> 1 p=[eval(x) for x in input("enter info").split()]
#       2 print(p)
#       3 for i in range(len(p)):
#
# File <string>:1
#
# NameError: name 'jiya' is not defined

# %%
p=[eval(x) for x in input("enter info").split()]
print(p)
# Out:
# enter info jiya
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 p=[eval(x) for x in input("enter info").split()]
#       2 print(p)
#
# File <string>:1
#
# NameError: name 'jiya' is not defined
