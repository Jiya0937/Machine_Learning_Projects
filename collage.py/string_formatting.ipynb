# %%
# 5 operator method
a,b=10,20
print("a is %i and b is %i " %(a,b))
# Out:
# a is 10 and b is 20

# %%
name="jiya"
salary=1000000
collage='acropolis'
# f string method
print(f"hello {name} your salary is {salary} and your collage is {collage}")
# Out:
# hello jiya your salary is 1000000 and your collage is acropolis

# %%
#format() method
print("hii {} your collage is {} and your salary is {}".format(name,collage,salary))
# Out:
# hii jiya your collage is acropolis and your salary is 1000000

# %%
# keywod argument(for proper formating of variable)
print("hii {x} your collage {y} and your salary {z}".format(y=collage,z=salary,x=name))
# Out:
# hii jiya your collage acropolis and your salary 1000000

# %%
# flow control
"""types--
1.conditional statement : varieties :{if,if else,if elif else}
            (a) if----> if condition:
                        statement 1
                        statement 2
                        example : if a>b:
                              print(a)
2.iterative stratment
3.transfer stratement"""

# %%
a=int(input("enter no : "))
if a%2==0:
    print('number is even')
else:
    print("number is odd")
# Out:
# enter no :  6
# number is even

# %%
a=int(input("enter a : "))
b=int(input("enter b : "))
if a>b:
    print("a is greater ")
else:
    print("b is greater")
# Out:
# enter a 3
# enter b 2
# a is greater than b

# %%
n=int(input("enter number : "))
if n>=1 and n<=100:
    print("nunber lie between 1 to 100 range")
else:
    print("out of range")
# Out:
# enter number 555
# out of range

# %%
brand=input("enter your brand")
if brand=='lays':
    print("purchase chips")
elif brand=='amul':
    prin("buy amul butter")
elif brand=='zudio':
    print("buy cloths")
else:
    print("buy tedhemedhe")
# Out:
# enter your brand lays
# purchase chips
