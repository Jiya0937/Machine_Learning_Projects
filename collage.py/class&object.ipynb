# %%
# class : **class is a user defined datatype**,it is blue print or design of object

# %%
# object : **object is a variable of class type**,onject is copy or peoduct of object,real world entities

# %%
# it is defined for solve the real world problems,and connect the problems with real world problems

# %%
# (in c++)private and public : access specifier
# function define in class is called member function(in python function called method)
# in python variable define in class is called attribute

# %%
# there are three Types of attribute(variacle)
'''1.instance variable: (also called object level variable because their value is differernt for all object)
2.local variable : (variable define in methods for perfoming any perticular task that variavle or attribute is called local variable)
3.static variable : (value of all the variable is same for all object)'''

# there are three Types of methods(function)
'''1.instance variable
2.local variable
3.static variable'''
