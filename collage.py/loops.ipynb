# %%
name=""
password=None
while name!="jiya" or password != 9456:
    name=input("enter name : ")
    password = int(input("enter password : "))
print("thank you")
# Out:
# enter name :  jiya
# enter password :  8764
# enter name :  jihd
# enter password :  9456
# enter name :  hgsjg
# enter password :  73486
# enter name :  jiya
# enter password :  9456
# thank you

# %%
for i in range(5):
    for j in range(4):
        print("*",end="")
    print()
# Out:
# ****
# ****
# ****
# ****
# ****

# %%
for i in range(1,4):
    for j in range(4):
        print(i,end="")
    print()
# Out:
# 1111
# 2222
# 3333

# %%
for i in range(1,4):
    for j in range(1,4):
        print(j,end="")
    print()
# Out:
# 123
# 123
# 123

# %%
for i in range(5):
    for j in range(0,i):
        print("*",end="")
    print()
# Out:
# *
# **
# ***
# ****

# %%
for i in range(5):
    for j in range(0,5-i):
        print("*",end="")
    print()
# Out:
# *****
# ****
# ***
# **
# *

# %%
for i in range (5):
    for j in range(0,5-i):
        print(" ",end="")
    for j in range(0,i):
        print("*",end="")
    print()
# Out:
#
#     *
#    **
#   ***
#  ****

# %%
for i in range (5):
    for j in range(0,5-i):
        print(" ",end="")
    for j in range(0,i):
        print("*",end=" ")
    print()
# Out:
#
#     *
#    * *
#   * * *
#  * * * *

# %%
for i in range (5):
    for j in range(0,5-i):
        print(" ",end="")
    for j in range(0,i):
        print("*",end=" ")
    print()
for i in range (5,0,-1):
    for j in range(0,5-i):
        print(" ",end="")
    for j in range(0,i):
        print("*",end=" ")
    print()
# Out:
#
#     *
#    * *
#   * * *
#  * * * *
# * * * * *
#  * * * *
#   * * *
#    * *
#     *
