# %%
l = []
l.append("jiya")
l.append ("aiml")
l.append("18")
print(l)

l.remove("jiya")
l
# Out:
# ['jiya', 'aiml', '18']
# ['aiml', '18']

# %%
# strip() function uses to remove space from start and end

fruit =  ["mango",'apple','papaya','banana','orange']
choose =input("enter your fruit")
if choose.strip() in fruit:
    print("yes exists")
else:
    print("not exists")
# Out:
# enter your fruit  papaya
# yes exists

# %%
s = "this is my collage"
s.find("is")
s.rfind("my")
# Out:
# 8

# %%
#count
info = ("the name of our collage is acropolis and our collage is very nice")
info.count("collage")
# Out:
# 2

# %%
# replace
demo = ("now i am learning python")
print(demo.replace('python','SQL'))
# Out:
# now i am learning SQL

# %%
# split
name =  ("my name is jiya")
print(name.split())
# Out:
# ['my', 'name', 'is', 'jiya']

# %%
# split on the basic of symbols
dob =  "19/01/2007"
print(dob.split('/'))
# Out:
# ['19', '01', '2007']

# %%
intro = ("my name is jiya deshmukh")
print(intro.title())
# Out:
# My Name Is Jiya Deshmukh

# %%
# if sentence is lower case so convert into capital and vice versa
print(intro.swapcase())
# Out:
# MY NAME IS JIYA DESHMUKH

# %%
print(intro.capitalize())
# Out:
# My name is jiya deshmukh

# %%
print(intro.upper())
# Out:
# MY NAME IS JIYA DESHMUKH

# %%
print(intro.lower())
# Out:
# my name is jiya deshmukh

# %%
intro = ("my name is jiya deshmukh")

l=[]
for i in range(len(intro)):
    if intro[i]!=" ":
        l.append(intro[i])
print(l)
# Out:
# ['m', 'y', 'n', 'a', 'm', 'e', 'i', 's', 'j', 'i', 'y', 'a', 'd', 'e', 's', 'h', 'm', 'u', 'k', 'h']

# %%
l=["python" , "is","easy"]
j=' '.join(l)
j
# Out:
# 'python is easy'

# %%
i= ["learning",'python','is','very','difficult']
r='very'
if r in i:
    i.remove(r)
print(i)
print(' '.join(i))
# Out:
# ['learning', 'python', 'is', 'difficult']
# learning python is difficult

# %%
intro = ("my name is jiya deshmukh")
print(intro.startswith('is'))
print(intro.endswith('deshmukh'))
# Out:
# False
# True

# %%
# convert into ascie value
# chr and ord
print(chr(65))
print(ord('A'))
# Out:
# A
# 65

# %%
info = ("my name is jiya deshmukh")
l=info.split()
rev=[]
for i in range (len(l)-1,0,-1):
    rev.append(l[i])
print(rev)
# Out:
# ['deshmukh', 'jiya', 'is', 'name']

# %%
info = ("my name is jiya deshmukh")
l=info.split()
rev=[]
m=[]
for i in range(0,len(l)):
    word = l[i]
    rev.append(word[::-1])
print(rev)
# Out:
# ['ym', 'eman', 'si', 'ayij', 'hkumhsed']

# %%
# DEEO copy : point different oblect
# how to achive cloning
#1st way by slicing
l1=[4,5,6,4]
l2=l1[:]
print(id(l1))
print(id(l2))
# Out:
# 2062134107136
# 2062134228160
