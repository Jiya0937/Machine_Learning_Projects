# %%
data=("hii everyone \n here i am jiya \n i want to teach you javascript \n can i start learning  ")
f=open("practicejiya.txt","w")
line=f.write(data)
f.close()

# %%
f=open("practicejiya.txt","r")
print(f.read())
f.close()
replaces=data.replace("javascript","pyhton")
f=open("practicejiya.txt","w")
f.write(replaces)
f.close()
# Out:
# hii everyone
#  here i am jiya
#  i want to teach you pyhton
#  can i start learning

# %%
word="my collage name is carrer academy \n and school is acropolis "
with open("p.txt","w") as f:
    f.write(word)

# %%
with open("p.txt","r") as f:
    print(f.read())
    
new=word.replace("collage","acropolis")
new=word.replace("school","collage")
print(new)
# Out:
# my collage name is carrer academy
#  and school is acropolis
# my collage name is carrer academy
#  and collage is acropolis

# %%
#fetch whole words in website
content=library.getText()   
add2=content

#text file open / write / 
f=open("web_python.txt","w+",encoding="utf-8")
f.write(add2)
f.close()

name={}
count=1
word=add2.split()
for i in range (0,len(word)):
    if word[i].isalpha():
        if word[i] in name:
            count+=1
            name[word[i]]=count
        else:
            name[word[i]]=count
           
print(name,end="")
