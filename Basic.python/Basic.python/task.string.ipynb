# %%
#clean a customer name string

name="jOhN doE"
print(name.title())
print(f"jOhN doE".title())
# Out:
# John Doe
# John Doe

# %%
#Exact Domain Name from Email

email_id="user@example.com"
print(email_id[5::])
# Out:
# example.com

# %%
#replace substring in job title
print(f"Junior Data Scientist".replace("Junior","Senior"))
# Out:
# Senior Data Scientist

# %%
#count keyword appearance in feedback
print(f"Data science is all about data.and more data".count("data"))
# Out:
# 2
