# %% [markdown]
# # ATM

# %%
print(("----------Welcome to panjab national bank----------").upper())
an = [9981263238,6232150937,6232743238,9399143722,7000432434,9977969791,89826631114]
pin=int(input("Enter The Pin :").upper())
u=int(input("Enter Your Bank Account Number :"))


if (u in an and pin==3238):
    print (("----------Welcome to panjab national bank--------p--").upper())
    print("Details : ")
    print(f"NAME           : SARITA DESHMUKH")
    print(f"ACCOUNT NUMBER : {u}")
    print(f"IFSCE CODE     : INO38583238")
elif (u in an and pin==9937):
    print (("----------Welcome to panjab national bank--------p--").upper())
    print("Details : ")
    print(f"NAME           : (JIYA DESHMUKH")
    print(f"ACCOUNT NUMBER : {u}")
    print(f"IFSCE CODE     : INO38F7939937")
elif (u in an and pin==1007):
    print (("----------Welcome to panjab national bank--------p--").upper())
    print("Details : ")
    print(f"NAME           : RIYA DESHMUKH")
    print(f"ACCOUNT NUMBER : {u}")
    print(f"IFSCE CODE     : INO38F7931007")
elif (u in an and pin==6677):
    print (("----------Welcome to panjab national bank--------p--").upper())
    print("Details : ")
    print(f"NAME           :  RADHESYAM DARWAI")
    print(f"ACCOUNT NUMBER : {u}")
    print(f"IFSCE CODE     : INO38F7936677")
elif (u in an and pin==2768):
    print (("----------Welcome to panjab national bank--------p--").upper())
    print("Details : ")
    print(f"NAME           :  SANDHYA VISHWAKARMA")
    print(f"ACCOUNT NUMBER : {u}")
    print(f"IFSCE CODE     : INO38F7932768")
# Out:
# ----------WELCOME TO PANJAB NATIONAL BANK----------
# Enter The Pin : 3238
# Enter Your Bank Account Number : 6232150937
# ----------WELCOME TO PANJAB NATIONAL BANK--------P--
# Details :
# NAME           : SARITA DESHMUKH
# ACCOUNT NUMBER : 6232150937
# IFSCE CODE     : INO38583238
