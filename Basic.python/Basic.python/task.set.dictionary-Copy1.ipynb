# %%
touple=("jiya","sandhya"",aditya","sandhya","jiya")
st=0
end=4
if (touple[st]==touple[4]): 
    st+=1
    end-=1
else:
    print("not palindrom")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 4
#       2 st=0
#       3 end=len(touple)
# ----> 4 if (touple[st]==touple[end]):
#       5     st+=1
#       6     end-=1
#
# IndexError: tuple index out of range

# %%
name=int(input(f"enter the product name{})
product=[{"name"="product1","price":10.5},{name="product2","price":15.0}]

# %%
#Write a Python function to reverse a string without using built-in reverse functions.
#The function should take a string as input and return the reversed string.
#Input: "hello"
#Expected Output: "olleh"#

s="hello"
k=len(s)
for i in range (k,0,-1):
    print(s[i],end="")
k
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[10], line 9
#       7 k=len(s)
#       8 for i in range (k,0,-1):
# ----> 9     print(s[i],end="")
#      10 k
#
# IndexError: string index out of range

# %%
#Write a Python function to reverse a string without using built-in reverse functions.
#The function should take a string as input and return the reversed string.
#Input: "hello"
#Expected Output: "olleh"#

s="hello"
print(s[4::-1])
# Out:
# olleh

# %%
name=int(input(f"enter the product name{})
product=[{"name"="product1","price":10.5},{name="product2","price":15.0}]

# %%
j="Assessment"

print(j.count('A'),j.count('s'),j.count("e"),j.count('m'),j.count("n"),j.count('t'))
# Out:
# 1 4 2 1 1 1

# %%
dic={"name":"product1",
     "prize":10.5,
     "name":"product2",
     "prize":15.0}
print(dic.value())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 5
#       1 dic={"name":"product1",
#       2      "prize":10.5,
#       3      "name":"product2",
#       4      "prize":15.0}
# ----> 5 print(dic.value())
#
# AttributeError: 'dict' object has no attribute 'value'

# %%
d=[{"name":"product1","prize":10.5},{"name":"product2","prize":15.0}]

print(d)
print(d.value(name))
# Out:
# [{'name': 'product1', 'prize': 10.5}, {'name': 'product2', 'prize': 15.0}]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[17], line 3
#       1 d=[{"name":"product1","prize":10.5},{"name":"product2","prize":15.0}]
#       2 print(d)
# ----> 3 print(d.value(name))
#
# AttributeError: 'list' object has no attribute 'value'
