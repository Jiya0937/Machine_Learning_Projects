# %%
a=10
b=9
a,b=b,a

print(a,b)
# Out:
# 9 10

# %%
s=[1,3,2,3,2,5]
h=set(s)
h
# Out:
# {1, 2, 3, 5}

# %%
s=[1,3,2,3,2,5]
g=[]
for i in range (0,len(s)):
    for j in range (1,len(s)):
        if s[i]==s[j]:
            g.append(s[i])
            print(s[j],end="")
# Out:
# 332233225

# %%
s=[1,3,2,3,2,5]
print(max(s))
# Out:
# 5

# %%
(sort(s))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(sort(s))
#
# NameError: name 'sort' is not defined

# %%
name="my name is jiya deshmukh or jiya deshmukh is my name"
string=""
real=[]
for i in range(len(name)):
    if name[i]!=" ":
        string=string+name[i]
    else:
        name[i]==" "
        (real.append(string))
        string=""
print(real)
count=1
dic={}
i=0
j=1
count=1
while i<len(real):
    while j<len(real):
        if real[i]==real[j]:
            count+=1
        else:
            count=1
    dic={real[i]:count}
print(dic)

# %%
name="my name is jiya deshmukh or jiya deshmukh is my name"
listing=[]
for i in range(len(name)):
    if name[i]!=" ":
        string=string+name[i]
        if name[i]==" ":
            listing.append(string)
print(listing)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 5
#       3 for i in range(len(name)):
#       4     if name[i]!=" ":
# ----> 5         string=string+name[i]
#       6         if name[i]==" ":
#       7             listing.append(string)
#
# NameError: name 'string' is not defined

# %%
name="my name is jiya deshmukh or jiya deshmukh is my name"
listing=[]
for i in range (3):
    name2=input()
    listing.append(name2)
print(listing)
# Out:
#  y
#  k
# ['y', 'k', '']

# %%
l=[]
for i in range(6):
    name=input()
    l.append(name)
l
# Out:
#  j
#  k
#  l
#  z
#  m
#  b
# ['j', 'k', 'l', 'z', 'm', 'b']

# %%
name="my name is jiya deshmukh or jiya deshmukh is my name"
string=""
real=[]
for i in range(len(name)):
    if name[i]!=" ":
        string=string+name[i]
    else:
        name[i]==" "
        (real.append(string))
        string=""
print(real)
count=1
dic={}
i=0
j=1
count=1
while i<len(real):
    while j<len(real):
        if real[i]==real[j]:
            count+=1
        else:
            count=1
    dic={real[i]:count}
print(dic)

# %%
string=""
real=[]
for i in range(len(content)):
    if content[i]!=" ":
        string=string+content[i]
    else:
        content[i]==" "
        (real.append(string))
        string=""
print(real)
