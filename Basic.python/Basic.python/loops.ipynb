# %%
n=6
for i in range(1,n):
    for j in range(i):
        print("*",end="")
    for k in range(n-i):
        print (" ",end=" ")
    for l in range(i):
        print ("*",end="")
    print()
for i in range(n,0,-1):
    for j in range(i):
        print("*",end="")
    for k in range(n-i):
        print (" ",end=" ")
    for l in range(i):
        print ("*",end="")
    print()
# Out:
# *          *
# **        **
# ***      ***
# ****    ****
# *****  *****
# ************
# *****  *****
# ****    ****
# ***      ***
# **        **
# *          *

# %%
n=7
for i in range(0,n):
    for j in range(0,1):
        print("*",end=" ")
    for k in range(1,n-1):
        if(i==0 or i==n-1):
            print("*",end=" ")
        else:
            print(" ",end=" ")
    for j in range(0,1):
        print("*",end=" ")
    print()
# Out:
# * * * * * * *
# *           *
# *           *
# *           *
# *           *
# *           *
# * * * * * * *

# %%
n=3
for i in range(0,n):
    for j in range(n,0,-1):
        print("*",end="")
    print()
# Out:
# ***
# ***
# ***

# %%
n=6
for i in range(n,0,-1):
    for j in range(i):
        print("*",end="")
    for k  in range(i-1):
        if()
        print()
    print()
# Out:
# ******
# *****
# ****
# ***
# **
# *

# %%
for i in range (0,7):
    for j in range (7-i):
        print("*",end=" ")
   
        
    print()
# Out:
# * * * * * * *
# * * * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range (0,7):
    for j in range (7-i):
        print(" ",end=" ")
    for k in range (7-i,8-i):
        print ("*",end="")
    for l in range (0,i):
        print("   ",end=" ")
    for k in range (7-i,8-i):
        if(i!=0):
            print ("*",end="")
            
   
    print()
for i in range (0,11):
    print("*",end="  ")
# Out:
#               *
#             *    *
#           *        *
#         *            *
#       *                *
#     *                    *
#   *                        *
# *  *  *  *  *  *  *  *  *  *  *

# %%
print("print matrix a :")
for i in range (0,3):
    for j in range (0,3):
       
        globals()[f"a{i}{j}"] = int(input())
print("print matrix b :")
for i in range (0,3):
      
    for j in range (0,3):
        globals()[f"b{i}{j}"] = int(input())
print("sun of a and b :")
for i in range (0,3):
    for j in range (0,3):
        print(globals()[f"a{i}{j}"]+globals()[f"b{i}{j}"],end=" ")
   
    print()
# Out:
# print matrix a :
#  1
#  2
#  3
#  4
#  5
#  6
#  7
#  8
#  9
# print matrix b :
#  9
#  8
#  7
#  6
#  5
#  4
#  3
#  2
#  1
# sun of a and b :
# 10 10 10
# 10 10 10
# 10 10 10

# %%
print("enter matrix a")
for i in range (0,3):
    for j in range (0,3):
        globals()[f"a{i}{j}"] = int(input())
print("enter matrix b")
for i in range (0,3):
    for j in range (0,3):
        globals()[f"b{i}{j}"] = int(input())
print("sunstraction of matrix a and b is :")
for i in range (0,3):
    for j in range (0,3):
        print(globals()[f"a{i}{j}"]-globals()[f"b{i}{j}"],end="")
    print()
# Out:
# enter matrix a
#  1
#  4
#  7
#  8
#  9
#  6
#  3
#  2
#  5
# enter matrix b
#  1
#  4
#  7
#  8
#  9
#  6
#  3
#  2
#  5
# sunstraction of matrix a and b is :
# 000
# 000
# 000

# %%
n=2
print("enter matrix a")
for i in range (0,n):
    for j in range (0,n):
        globals()[f"a{i}{j}"] = int(input())
print("enter matrix b")
for i in range (0,n):
    for j in range (0,n):
        globals()[f"b{i}{j}"] = int(input())
for i in range (0,n):
    for j in range (0,n):
        r=0     
        for k in range (0,n):
            r+=(globals()[f"a{i}{k}"]*globals()[f"b{k}{j}"])
        print(f"{r}",end=" ")
    print()
# Out:
# enter matrix a
#  1
#  2
#  3
#  4
# enter matrix b
#  5
#  6
#  7
#  8
# 19 22
# 43 50
