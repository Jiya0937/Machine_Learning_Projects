# %%
Name = input("Enter your name:")
f=open("Information.txt","w")
f.write(Name)
f.close()
# Out:
# Enter your name: Vicky Jaiswal

# %%
f=open("Information.txt","r")
d=f.read(3)
k=f.read(4)
print(d,k)
f.close()
# Out:
# Vic ky J
