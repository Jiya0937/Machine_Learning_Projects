# %%
class student:
    def classes1():
        name="jiya deshmukh"
        branch="aiml"
        collage="acropolis"
s1=student
print(s1.classes1)
# Out:
# <function student.classes1 at 0x000002EB2BCD5580>

# %%
class car:
    name=bmw
