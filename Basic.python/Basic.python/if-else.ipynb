# %% [markdown]
# ## is-else and input function
#
# x=int(input("enter the value of x :").title())
#
# if x%2==0:
#     print("Number is prime")
# else:
#     print("Number is not prime")

# %% [markdown]
# # if-else Task-4

# %%
#Task 1: E-Commerce Discount Engine
#Problem: Apply tiered discount on cart checkout.

prize=int(input("Enter the price of product :"))
if 2000<=prize<=5000:
    print("Discount               : 10%")
    discount=prize*0.1
    print(f"Discount Money         : {discount}")
    prize=prize-discount
    print(f"Total prize of poduct  : {prize}")
elif prize>=5000:
    print("Discount               : 20%")
    discount=prize*0.2
    print(f"Discount Money         : {discount}")
    prize=prize-discount
    print(f"Total prize of poduct  : {prize}")
else:
    print("No Discount")
# Out:
# Enter the price of product : 15000
# Discount               : 20%
# Discount Money         : 3000.0
# Total prize of poduct  : 12000.0

# %%
#Task 2: Smart Notification Routing
#Problem Description: Notification systems often personalize delivery based on user preferences and message importance. For instance, if the message is critical or if the user wants to receive all messages, the notification should be sent. If the message is promotional and the user prefers only important messages, it should be skipped. This logic helps optimize user experience in apps.

message = (input("Enter the message type is critical or important or pramotion :"))
pramotion=(input("Enter the pramotion type is  all or important only or none    :"))

if message=='critical':
    print("sent to all")
     
elif message=="critical" and pramotion=="all":
    print("sent message to all")

elif message=="important" and pramotion=="important only":
    print("send to all")
else:
    print("none")

# %%
#Task 3: Booking Confirmation Based on Availability and Payment
#Problem Description: In a real-world booking system like a movie, travel, or hotel app, bookings should only go through if the requested seat or room is available and the payment has been successfully processed. This ensures the user cannot reserve without paying or take an unavailable slot.
seat=(input("enter the seat is available or not available :"))
payment=(input("Enter the payment is done or not"))
if seat=="available" and payment=="done":
    print ("seat is confirmed")
else:
    print ("seat is not confirmed")
# Out:
# enter the seat is available or not available : available
# Enter the payment is done or not done
# seat is confirmed

# %%
#Task 4: Dynamic Pricing Based on Time Slot
#Problem Description: In ride-booking apps or food delivery platforms, dynamic pricing is applied during peak hours to manage demand. For example, from 6 AM to 9 AM and 6 PM to 9 PM, the fare is increased. The system should check the current hour and apply pricing logic accordingly.
time=int(input("Enter the time between 1 to 24 hours"))
if 6<=time<=9 or 18<=time<=21:
    print("food prize is high".capitalize())
else:
    print("food prize is average".capitalize())
# Out:
# Enter the time between 1 to 24 hours 12
# Food prize is average

# %%
#Task 5: Employee Shift Assignment Based on Day
#Problem Description: In a factory or support center, employees work in shifts. For example, Shift A could be for Monday/Tuesday, Shift B for Wednesday/Thursday, and weekends may have special shifts. Write a logic that assigns employees based on the current day.
day=(input("Enter the day :"))
if day=="monday" or day=='tuesday':
    print('Assigned to shift A')
elif day=='wednesday' or day=='thuesday':
    print('Assigned to shift B')
else:
    print('Special shift')
# Out:
# Enter the day : monday
# Assigned to shift A

# %%
#Problem 6: Multi-Category Grading System
#A student receives scores in 3 subjects: Math, Science, and English. You must determine the final grade based on the following rules:

marks=(input("Enter tha marks :"))
if marks>=90
   print("Grate A+")
elif 80<=marks<90:
