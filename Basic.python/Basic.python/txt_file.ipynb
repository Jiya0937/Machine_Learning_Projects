# %% [markdown]
# # file

# %%
name=input("enter name")
f=open("show_name.txt","w")
f.write(name)
f.close()
# Out:
# enter name jiya deshmukh

# %%
name=["jiya,sandhya,aditya"]
f=open("show_name.txt","w")
f.writelines(name)
f.close()

# %%
f=open("show_name.txt","r") 
s=f.read(19)
print(s)
f.close()
# Out:
# jiya,sandhya,aditya
