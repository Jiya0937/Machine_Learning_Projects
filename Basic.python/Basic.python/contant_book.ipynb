# %%
def content(jiya,sandhya,aditya):
    jiya={
        "name":"jiya deshmukh",
        "phone":6232150937,
        "email":"jiyadeshmukh389@gmmail.com"
    }
    sandhya={
        "name":"sandhya vishwakarma",
        "phone":7000432434,
        "email":"sandhyavishwakarma@gmmail.com"
    }
    aditya={
        "name":"aditya chodhary",
        "phone":9934676374,
        "email":"adityachodhary@gmmail.com"
    }
content(jiya,sandhya,aditya)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 17
#       7     sandhya={
#       8         "name":"sandhya vishwakarma",
#       9         "phone":7000432434,
#      10         "email":"sandhyavishwakarma@gmmail.com"
#      11     }
#      12     jiya={
#      13         "name":"aditya chodhary",
#      14         "phone":9934676374,
#      15         "email":"adityachodhary@gmmail.com"
#      16     }
# ---> 17 content(jiya,sandhya,aditya)
#
# NameError: name 'jiya' is not defined

# %%
n=input(f"FullName : ")
if n=="jiya":
    j={"name":"jiya deshmukh",
        "phone":6232150937,
        "email":"jiyadeshmukh389@gmmail.com"
    }
elif n=="sandhya":
    sandhya={
        "name":"sandhya vishwakarma",
        "phone":7000432434,
        "email":"sandhyavishwakarma@gmmail.com"
    }
    aditya={
        "name":"aditya chodhary",
        "phone":9934676374,
        "email":"adityachodhary@gmmail.com"
    }
    print(j)
# Out:
# FullName :  jiya
# {'name': 'jiya deshmukh', 'phone': 6232150937, 'email': 'jiyadeshmukh389@gmmail.com'}

# %%
add=[]
def
