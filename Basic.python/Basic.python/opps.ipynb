# %%
class calculator:
    def multi(self,a,b):
        return a*b
    def div(self,a,b):
        return a/b
s=calculator()
s.multi(10,5)
# Out:
# 50

# %%
s.div(19,2)
# Out:
# 9.5

# %%
class student:
    name="jiya"
s1=student()
print(s1.name)
# Out:
# jiya

# %%
class student:
    name="jiya"
    classroom="AIML"
s1=student()
print(s1.name)
print(s1.classroom)
# Out:
# jiya
# AIML

# %%
class teacher:
    def __init__(self):
        print(self)
        print("name = shushma joshi")
        print("education = profesor degree")
t1=teacher()
# Out:
# ...
# name = shushma joshi
# education = profesor degree

# %%
class student:
    def __init__(self,firstname,branch):
        self.name=firstname
        self.dep=branch
        
        
s1=student("jiya",", aiml")
print(s1.name,s1.dep)
s2=student("jiyadeshmukh",", cse")
print(s2.name,s2.dep)
# Out:
# jiya , aiml
# jiyadeshmukh , cse

# %%
class student:
    collage_name="Acropolis"
    Address_name="Mangaliya , indore"
    def __init__(self,sname,sdep):
        self.name=sname
        self.dep=sdep
s1=student("krish kapoor","Aiml")
print(s1.name,s1.dep)
print(student.collage_name)
print(student.Address_name)
# Out:
# krish kapoor Aiml
# Acropolis
# Mangaliya , indore

# %%
#task1
class student:
    def __init__(self,sname,sgrade,sbranch,ssgpa):
        self.name=sname
        self.grade=sgrade
        self.branch=sbranch
        self.sgpa=ssgpa
s1=student("Radhika","A+","CSE","8.24")
print(s1.name,s1.grade,s1.branch,s1.sgpa)
# Out:
# Radhika A+ CSE 8.24

# %%
class student:
    def __init__(self,name,sub1,sub2,sub3):
        self.name=name
        self.sub1=sub1
        self.sub2=sub2
        self.sub3=sub3
s1=student("name","maths","physics","chemistry")
print(s1.name,s1.sub1,s1.sub2,s1.sub3)
# Out:
# name maths physics chemistry

# %%
class person:
    def info(date,catagory):
        self.date=date
        info.catagory=catagory
p1=person()
p1.info("7 octomber 2025","vegetarian")
print(info.date,info.catagory)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 5
#       3         info.date=date
#       4         info.catagory=catagory
# ----> 5 p1=person("17 octomber 2025","vegetarian")
#       6 print(info.date,info.catagory)
#
# TypeError: person() takes no arguments

# %%
#2. Student Marks Record
#Create a class to store student details and marks.
#Attributes: student name, roll number, marks in 3 subjects.
#Methods: calculate total marks, calculate average, display result
class student:
    def __init__(self,name,rollno,m1,m2,m3):
        self.name=name
        self.rollno=rollno
        self.m1=m1
        self.m2=m2
        self.m3=m3
    def total(self):
        return self.m1+self.m2+self.m3
    def average(self):
        return self.total()/3
    def complete(self):
        print("Name : " ,self.name)
        print("Roll no : " ,self.rollno)
        print("Total Marks : ",self.total())
        print("Average : ",self.average())
s1=student("jiya Deshmukh","63",93,90,89)
s1.complete()
# Out:
# Name :  jiya Deshmukh
# Roll no :  63
# Total Marks :  272
# Average :  90.66666666666667

# %%
class daily_expenses:
    def expenses(self,travel,food,shoping,dinner):
        self.travel=travel
        self.food=food
        self.shoping=shoping
        self.dinner=dinner
    def total(self):
        return self.travel + self.food + self.shoping + self.dinner
    def final(self):
        print("=====Expenses with Category=====")
        print("Travelling   : ",self.travel)
        print("Food         : ",self.food)
        print("Shoping      :",self.shoping)
        print("Dinner       : ",self.dinner)
        print("Total Amount : ", self.total())
E1=daily_expenses()
E1.expenses(1000,900,5000,2000)
E1.final()
# Out:
# =====Expenses with Category=====
# Travelling   :  1000
# Food         :  900
# Shoping      : 5000
# Dinner       :  2000
# Total Amount :  8900

# %%
class shop:
    def expenses(self,travel,food,shoping,dinner):
        self.travel=travel
        self.food=food
        self.shoping=shoping
        self.dinner=dinner
    def devices_quantity(self,mobile,blutooth,laptop,keyboard,mouse):
        self.mobile=mobile
        self.bluetooth=bluetooth
        self.laptop=laptop
        self.keyboard=keyboard
        self.mouse=mouse=mobile
    def prize(self,pmobile,pblutooth,plaptop,pkeyboard,pmouse):
        self.pmobile=pmobile
        self.pbluetooth=pbluetooth
        self.plaptop=plaptop
        self.pkeyboard=pkeyboard
        self.pmouse=pmouse
    def prizes(self):
        total _mobile=(self.pmobile*self.mobile)
        total_iphone=
    print("total prize",self.prizes)
        
    
s1=shop
s1.expenses
s1.devices_quantity(3,4,5,7,2)
s1.prize(50000,1000,100000,500,200)
s1.total_money()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 class shop:
#       2     def expenses(self,travel,food,shoping,dinner):
#       3         self.travel=travel
#
# Cell In[43], line 21, in shop()
#      19 def prizes(self):
#      20     return self.pmobile*self.mobile
# ---> 21 print("total prize",self.prizes)
#
# NameError: name 'self' is not defined

# %%
self.tblutooth=self.pbluetooth*self.blutooth
        self.tlaptop=self.plaptop*self.laptop
        self.tkeyboard=self.pkeyboard*self.keyboard
        self.tmouse=self.pmouse*self.mouse
def total_money(self):
        self.tmobile+self.tblutooth+self.tlaptop+self.tkeyboard+self.tmouse
    print("total money",self.total_money

# %%
class shop:
    def product(self,mobile,iphone,speaker,mouse,keyboard):
        self.mobile=mobile
        self.iphone=iphone
        self.speaker=speaker
        self.mouse=mouse
        self.keyboard=keyboard
    def total(self):
        print("-----------Quantity of the product-----------")
        print("Mobile   : ",self.mobile)
        print("iphone   : ",self.iphone)
        print("Speaker  : ",self.speaker)
        print("Mouse    : ",self.mouse)
        print("keyboard : ",self.keyboard)
    def prize(self,pmobile,piphone,pspeaker,pmouse,pkeyboard):
        self.pmobile=pmobile
        self.piphone=piphone
        self.pspeaker=pspeaker
        self.pmouse=pmouse
        self.pkeyboard=pkeyboard
    def prize2(self):
        print("----------Prize of individual product----------")
        print("pMobile   : ",self.pmobile)
        print("piphone   : ",self.piphone)
        print("pSpeaker  : ",self.pspeaker)
        print("pMouse    : ",self.pmouse)
        print("pkeyboard : ",self.pkeyboard)
    def total_prize(self):
        print("mobile",print( self.pmobile*self.mobile))
    def final(self):
        print(self.total_prize())
    
s1=shop()
s1.product(9,9,8,4,3)
s1.total()
s1.prize(1000,2000,3000,4000,5000)
s1.prize2()
s1.final()
# Out:
# -----------Quantity of the product-----------
# Mobile   :  9
# iphone   :  9
# Speaker  :  8
# Mouse    :  4
# keyboard :  3
# ----------Prize of individual product----------
# pMobile   :  1000
# piphone   :  2000
# pSpeaker  :  3000
# pMouse    :  4000
# pkeyboard :  5000
# 9000
# mobile None
# None
