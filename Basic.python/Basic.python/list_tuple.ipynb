# %% [markdown]
# # list

# %%
# index
student=["aditya","jiya","sandhya"]
print(student[0])
# Out:
# aditya

# %%
# append 
student.append("vickysir")
print(student)
# Out:
# ['aditya', 'jiya', 'sandhya', 'vickysir']

# %%
#remove
intro=["jiya",18,'career academy']
intro.remove('jiya')
intro.remove(18)
print(intro)
# Out:
# ['career academy']

# %%
#pop
fruit=["mango",'banana','apple','papaya']
fruit.pop(3)
print(fruit)
# Out:
# ['mango', 'banana', 'apple']

# %%
#insert(i,x)
colors=["red","blue","white","navyblue","black"]
colors.insert(0,"orange")
print(colors)
# Out:
# ['orange', 'red', 'blue', 'white', 'navyblue', 'black']

# %%
#reverse
number=[1,3,5,7,9]
number.reverse()
print(number)
# Out:
# [9, 7, 5, 3, 1]

# %%
#sort
name=["jiya",'aditya','sandhya','ram']
name.sort()
print(name)
# Out:
# ['aditya', 'jiya', 'ram', 'sandhya']

# %%
# sort and than arrange according to length
name=["jiya",'aditya','sandhya','ram']
name.sort(key=len)
print(name)
# Out:
# ['ram', 'jiya', 'aditya', 'sandhya']

# %%
#sort and reverse
name=["jiya",'aditya','sandhya','ram']
name.sort(reverse=True)
print(name)
# Out:
# ['sandhya', 'ram', 'jiya', 'aditya']

# %%
#count
name=["jiya",'aditya','sandhya','ram','jiya']
print(name.count('jiya'))
# Out:
# 2

# %%
#indedx
name=["jiya",'aditya','sandhya','ram','jiya']
print(name.index('jiya'))
# Out:
# 0

# %%
#lenght
name=["jiya",'aditya','sandhya','ram','jiya']
print(len(name))
# Out:
# 5

# %%
#extent
veg=['palak','tomato',"potato","paneer"]
color=['red','black']
veg.extend(color)
print(veg)
# Out:
# ['palak', 'tomato', 'potato', 'paneer', 'red', 'black']

# %%
v = veg+color
v
# Out:
# ['palak', 'tomato', 'potato', 'paneer', 'red', 'black', 'red', 'black']

# %%
list1=[[1,2,3],[2,3,5],[5,6,0]]
list2=[[5,9,7],[1,2,3,],[4,7,8]]
print(list1,list2)
# Out:
# [[1, 2, 3], [2, 3, 5], [5, 6, 0]] [[5, 9, 7], [1, 2, 3], [4, 7, 8]]

# %% [markdown]
# # touple

# %%
marks=[10,20,30,40,50]
number=list((marks))
print(number)
# Out:
# [10, 20, 30, 40, 50]

# %%
persantage=(100,60,80,49,90)
number=list([persantage])
print(number)
# Out:
# [(100, 60, 80, 49, 90)]

# %%
colors=(120,130,149,159,169)
print(colors)
# Out:
# (120, 130, 149, 159, 169)

# %%
marks=(1,2,3,4,56,54,45,8,38,387,24,47,84,6,4,6,8,9,90)
print(marks.count(4))
# Out:
# 2

# %%
marks=(1,2,3,4,56,54)
marks.index(2)
# Out:
# 1

# %%
#maximum
marks=(1,2,3,4,56,54)
max(marks)
# Out:
# 56

# %%
#minimum
marks=(1,2,3,4,56,54)
min(marks)
# Out:
# 1

# %%
#sum
marks1=(1,2,3,4,56,54)
sum((marks1))
# Out:
# 120

# %%
#sorted
marks1=(1,2,3,4,56,54)
sorted((marks1))
# Out:
# [1, 2, 3, 4, 54, 56]

# %%
#sum
marks1=(1,2,3,4,56,54)
sum((marks1))
# Out:
# 120

# %%
#sum
marks1=(1,2,3,4,56,54)
sum((marks1))
# Out:
# 120

# %%
#any()
marks1=(0,0,3)
any((marks1))
# Out:
# True

# %%
#all
marks=(1,2,3,4,56,54)
all(marks)
# Out:
# True

# %%
marks=[1,2,3,4,56,54,2,1]
i=int(input(f"ENTER THE VALUE"))
marks.count(i)
# Out:
# ENTER THE VALUE 1
# 2

# %%
n=[1,2,3,4,56,54,2,1]
even=[]
odd=[]
for i in range (len(n)):
    if(n[i]%2==0):
        even.append(n[i])
    else:
        odd.append(n[i])
print(f"even number :{even}")
print(f"odd number :{odd}")
# Out:
# even number :[2, 4, 56, 54, 2]
# odd number :[1, 3, 1]

# %%
email=["email@.com.com","jiyadeshukh398@gmail.com","gamil@gmail.outlook"]
normal=[]
output=[]

for i in range(len(email)):
    x=(email[i].find("@"))
    if(x!=0):
        output.append(email[i][x+1:len(email[i])])
        
      
print(output) 

#seprated by ;

normal.append(';'.join(email))
print(normal)
# Out:
# ['.com.com', 'gmail.com', 'gmail.outlook']
# ['email@.com.com;jiyadeshukh398@gmail.com;gamil@gmail.outlook']

# %%
numbers=[123457890,9981263236,6232150937,9977969791,9399143722,7000432434]

if i in range(len(numbers)):
    numbers.sort()
print(numbers)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 3
#       1 numbers=[123457890,9981263236,6232150937,9977969791,9399143722,7000432434]
# ----> 3 if i in range(len(numbers)):
#       4     numbers.sort()
#       5 print(numbers)
#
# NameError: name 'i' is not defined

# %%
for i in range(5):
    for j in range(5):
        if i==1 or j==1:
            print("*",end="")
# Out:
# *********
