# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sb

# %%
#Program 2 — Fill Missing Values in Temperature Dataset

"""Problem:
A temperature sensor failed on some days.
Fill missing values using the mean temperature."""


df={
    "Dataset": [30, 32, None, 29, 28, None, 31]
}
df
# Out:
# {'Dataset': [30, 32, None, 29, 28, None, 31]}

# %%
data=pd.DataFrame(df)
data
# Out:
#    Dataset
# 0     30.0
# 1     32.0
# 2      NaN
# 3     29.0
# 4     28.0
# 5      NaN
# 6     31.0

# %%
update=data.fillna(30)
update
# Out:
#    Dataset
# 0     30.0
# 1     32.0
# 2     30.0
# 3     29.0
# 4     28.0
# 5     30.0
# 6     31.0

# %%
#Program 3 — Compare Product Performance
"""Problem:
Two products A and B are compared for sales performance over 6 months.
Show which product sold better and plot side-by-side."""

product={
    "Product_A":[200,250,300,280,270,290],
    "Product_B":[180,220,260,300,320,310]
}
product
# Out:
# {'Product_A': [200, 250, 300, 280, 270, 290],
#  'Product_B': [180, 220, 260, 300, 320, 310]}

# %%
data=pd.DataFrame(product)
data
# Out:
#    Product_A  Product_B
# 0        200        180
# 1        250        220
# 2        300        260
# 3        280        300
# 4        270        320
# 5        290        310

# %%
data.index=["Jan","Feb","Mar","Apr","May","Jun"]
data
# Out:
#      Product_A  Product_B
# Jan        200        180
# Feb        250        220
# Mar        300        260
# Apr        280        300
# May        270        320
# Jun        290        310

# %%
#bar chart by panda
data.plot(kind="bar")
# Out:
# <Axes: >

# %%
mean_a=data["Product_A"].mean()
print("mean of product a is :".title(),mean_a)
mean_b=data["Product_B"].mean()
print("mean of product b is :".title(),mean_a)
# Out:
# Mean Of Product A Is : 265.0
# Mean Of Product B Is : 265.0

# %%
# histogram chart
data.plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
#,task 
score={
    "marks":[20,89,58,89,78,67,76,56,45,90,90,23,34,67,56,56,78,78,89,90,9,45,67,89,78,49,48,90,85]
}
show=pd.DataFrame(score)
show
# Out:
#     marks
# 0      20
# 1      89
# 2      58
# 3      89
# 4      78
# 5      67
# 6      76
# 7      56
# 8      45
# 9      90
# 10     90
# 11     23
# 12     34
# 13     67
# 14     56
# 15     56
# 16     78
# 17     78
# 18     89
# 19     90
# 20      9
# 21     45
# 22     67
# 23     89
# 24     78
# 25     49
# 26     48
# 27     90
# 28     85

# %%
sb.histplot(x="marks",data=show,kde=True)
# Out:
# <Axes: xlabel='marks', ylabel='Count'>

# %%
#task 4
cafe={
    "cups":[1,2,3,1,5,5,7,2,3,4,4,5]
}

# %% [markdown]
# # statstics normal distribution

# %%
df=pd.read_csv("C:\\Users\\jiyad\\OneDrive\\Desktop\\stastics.com.csv")
df
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                      Kothanur      2 BHK      1200.0     2   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0     4  231.00    5
# 13196                     other      4 BHK      3600.0     5  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0     2   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0     4  488.00    4
# 13199              Doddathoguru      1 BHK       550.0     1   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2               Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                  Kothanur      2 BHK      1200.0     2   51.00    2
#
#    price_per_sqft
# 0            3699
# 1            4615
# 2            4305
# 3            6245
# 4            4250

# %%
df.price_per_sqft.describe()
# Out:
# count    1.320000e+04
# mean     7.920337e+03
# std      1.067272e+05
# min      2.670000e+02
# 25%      4.267000e+03
# 50%      5.438000e+03
# 75%      7.317000e+03
# max      1.200000e+07
# Name: price_per_sqft, dtype: float64

# %%
#sb.histplot(df.price_per_sqft,kde=True)

# %%
mean=df.price_per_sqft.mean()
print(mean)
# Out:
# 7920.336742424242

# %%
std_deviation=df.price_per_sqft.std()
std_deviation
# Out:
# 106727.16032810845

# %%
print(mean-3*std_deviation)
# Out:
# -312261.1442419011

# %%
print(mean+3*std_deviation)
# Out:
# 328101.8177267496

# %%
df[(df.price_per_sqft>328101.8177267496) | (df.price_per_sqft<-312261.1442419011)]
# Out:
#              location       size  total_sqft  bath  price  bhk  price_per_sqft
# 345             other  3 Bedroom        11.0     3   74.0    3          672727
# 1106            other  5 Bedroom        24.0     2  150.0    5          625000
# 4044   Sarjapur  Road  4 Bedroom         1.0     4  120.0    4        12000000
# 4924            other      7 BHK         5.0     7  115.0    7         2300000
# 11447      Whitefield  4 Bedroom        60.0     4  218.0    4          363333

# %%
df_no_outlier = df[(df.price_per_sqft<328101.8177267496) & (df.price_per_sqft>-312261.1442419011)]
print(df_no_outlier.shape)
# Out:
# (13195, 7)

# %%
df_no_outlier
# Out:
#                        location       size  total_sqft  bath   price  bhk  \
# 0      Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1              Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2                   Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3            Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                      Kothanur      2 BHK      1200.0     2   51.00    2
# ...                         ...        ...         ...   ...     ...  ...
# 13195                Whitefield  5 Bedroom      3453.0     4  231.00    5
# 13196                     other      4 BHK      3600.0     5  400.00    4
# 13197     Raja Rajeshwari Nagar      2 BHK      1141.0     2   60.00    2
# 13198           Padmanabhanagar      4 BHK      4689.0     4  488.00    4
# 13199              Doddathoguru      1 BHK       550.0     1   17.00    1
#
#        price_per_sqft
# 0                3699
# 1                4615
# ...

# %%
# zscore = distance between mean and standerd deviation

# %%
#add zscores column mean distance between mean and perticular standerd deviation
df["zscore"]=(df.price_per_sqft-df.price_per_sqft.mean())/df.price_per_sqft.std()
df.head()
# Out:
#                    location       size  total_sqft  bath   price  bhk  \
# 0  Electronic City Phase II      2 BHK      1056.0     2   39.07    2
# 1          Chikka Tirupathi  4 Bedroom      2600.0     5  120.00    4
# 2               Uttarahalli      3 BHK      1440.0     2   62.00    3
# 3        Lingadheeranahalli      3 BHK      1521.0     3   95.00    3
# 4                  Kothanur      2 BHK      1200.0     2   51.00    2
#
#    price_per_sqft    zscore
# 0            3699 -0.039553
# 1            4615 -0.030970
# 2            4305 -0.033875
# 3            6245 -0.015697
# 4            4250 -0.034390

# %%
mean=print(df.price_per_sqft.mean())
# Out:
# 7920.336742424242

# %%
std=print(df.price_per_sqft.std())
# Out:
# 106727.16032810845

# %%
#(height-mean)/standerd deviation
zscore=(3699-7920.336742424242)/106727.16032810845
zscore
# Out:
# -0.03955260056996457

# %%
df_no_outlier=df[(df.zscore>-3)&(df.zscore<3)]
df_no_outlier.shape
# Out:
# (13195, 8)
