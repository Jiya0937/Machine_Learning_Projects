# %%
#task2  for drawing of circle rectangle and line
import cv2
image=input("give me a image or image path :")
if image is None:
    print("image is not found")
    image=input("give exect image or path :")
else:
    ask=input("what you want [line] or [rectangle]) or [circle] : ")
    if ask=='line':
