# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\jiyad\anaconda3\lib\site-packages (4.12.0.88)
# Requirement already satisfied: numpy<2.3.0,>=2 in c:\users\jiyad\anaconda3\lib\site-packages (from opencv-python) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

# %%
image=cv2.imread("C:\\image1st\\New folder\\j.d.jpeg")
if image is  None:
    print("not loaded")
else:
    print("image loaded")
    resized=cv2.resize(image,(800,600))
    cv2.imshow("before image",image)
    cv2.imshow("Original image",resized)
#same original
    cv2.imwrite("new_image.png",resized)
    cv2.waitKey(0)
cv2.destroyAllWindows()
