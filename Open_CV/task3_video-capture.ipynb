# %%
import cv2

# %%
capture=cv2.VideoCapture(0)
while capture is True:
    print("what you want 1.read \n 2.show \n 3.record  ")
    user=input("0 or 1")
    if user==1:
        choice=input("what 1,2,3")
        if choice==1:
            ret, frame=capture.read()
            if not ret:
                print("could not read")
                break
        if choice==2:
            cv2.imshow("Webcam Feed",frame)
            if cv2.waitKey(1) & 0xFF == ord('q'):
                print("Quitting....")
                break
            capture.release
            cv2.destroyAllWindows()
        if choice==3:
            frame_width=int(capture.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height=int(capture.get(cv2.CAP_PROP_FRAME_HEIGHT))

            codec = cv2.VideoWritter_fourcc(*'XVID')
            recorder = cv2.VodeoWritter("my-writter.avi",codec,20,(frame_width,frame_height))

            while True:
                success,image = capture.read()
                if not success :
                    break
                recorder.write(image)
                cv2.imshow("Recording live",image)

                if cv2.waitkey(1) & 0xFF == ord('q'):
                    break
            camera.release()
            recorder.release()
            cv2.destrouAllWindows()
