# %%
import cv2

# %%
#read image
image = cv2.imread("C:\\image1st\\New folder\\j.d.jpeg")
if image is not None:
    print("image is found")
else:
    print("image is not found")

# %%
#show image
image = cv2.imread("")
if image is not None :
    cv2.imshow("you image is show",image)
    cv2.waitKey(0)
    cv2.ditroyAllWindow()
else:
    print("image is not found")

# %%
# save image
image = cv2.imread("C:\\image1st\\New folder\\j.d.jpeg")
if image is not None:
    cv2.imwrite("C:\\image1st\\New folder\\j.d.jpeg",image)
    print("image is saved")
else:
    print("image is not found")

# %%
#Gray scale or gray color image
import cv2
image=cv2.imread("C:\\image1st\\New folder\\cv2.jpeg")
if image is not None:
    gray=cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
    cv2.imshow("Grayscale Image",gray)
    cv2.waitKey(0)
    destroyAllWindow()

else:
    print("image is not found")
