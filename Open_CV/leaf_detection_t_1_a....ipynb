# %%
import cv2
import pandas as pd
import numpy as np

# %%
image = imread("C:\\image1st\\New folder\\leaf2.jpeg")
if image is None:
    print("image is not loaded")
    break
else:

# %%
import cv2
import numpy as np


def detect_defected_plants(image_path):
    image = cv2.imread(image_path)
    if image is None:
        print("image not found")
        return[]
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    filtered_contours = []
    for c in contours:
        area = cv2.contourArea(c)
        if 1000 < area < 80000:  # adjust these values as needed
            filtered_contours.append(c)

    sorted_contours = sorted(filtered_contours, key=cv2.contourArea, reverse=True)

    plants = ['A', 'B', 'C', 'D', 'E', 'F']
    defected_plants = []

    for i, cont in enumerate(sorted_contours[:len(plants)]):
        cv2.drawContours(image, [cont], -1, (0, 255, 0), 3)
        X, Y = cont[0][0]
        cv2.putText(image, plants[i], (X, Y + 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

    # detect defected plant
        mask = np.zeros_like(gray)
        cv2.drawContours(mask, [cont], -1, 255, -1)

    # crop plant area
        plant_region = cv2.bitwise_and(image, image, mask=mask)
        hsv = cv2.cvtColor(plant_region, cv2.COLOR_BGR2HSV)

        lower_brown1 = np.array([10, 100, 20])
        upper_brown1 = np.array([20, 255, 200])
        lower_brown2 = np.array([20, 100, 20])
        upper_brown2 = np.array([30, 255, 200])

        brown_mask1 = cv2.inRange(hsv, lower_brown1, upper_brown1)
        brown_mask2 = cv2.inRange(hsv, lower_brown2, upper_brown2)
        brown_mask = brown_mask1 + brown_mask2

        brown_pixels = cv2.countNonZero(brown_mask)
        total_pixels = cv2.countNonZero(mask)

        if total_pixels > 0:
            brown_ratio = (brown_pixels / total_pixels) * 100
            if brown_ratio > 5:  # threshold (tweak this)
                defected_plants.append(plants[i])
    print(defected_plants)

        

block1 = detect_defected_plants("C:\\image1st\\New folder\\block1_image.jpg")
block2 = detect_defected_plants("C:\\image1st\\New folder\\block2_image.jpg")
print(f"Defected plant in Block 1 : {block1}")
print(f"Defected plant in Block 2 : {block2}")
# Out:
# ['A', 'E']
# ['A', 'C']
# Defected plant in Block 1 : None
# Defected plant in Block 2 : None

# %%
import cv2
import numpy as np


def detect_defected_plants(image_path):
    image = cv2.imread(image_path)
    if image is None:
        print("image not found")
        return []
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

    filtered_contours = []
    for c in contours:
        area = cv2.contourArea(c)
        if 1000 < area < 80000:  # adjust these values as needed
            filtered_contours.append(c)

    sorted_contours = sorted(filtered_contours, key=cv2.contourArea, reverse=True)

    plants = ['A', 'B', 'C', 'D', 'E', 'F']
    defected_plants = []

    for i, cont in enumerate(sorted_contours[:len(plants)]):
        cv2.drawContours(image, [cont], -1, (0, 255, 0), 3)
        X, Y = cont[0][0]
        cv2.putText(image, plants[i], (X, Y + 5), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

        # detect defected plant
        mask = np.zeros_like(gray)
        cv2.drawContours(mask, [cont], -1, 255, -1)

        # crop plant area
        plant_region = cv2.bitwise_and(image, image, mask=mask)
        hsv = cv2.cvtColor(plant_region, cv2.COLOR_BGR2HSV)

        lower_brown1 = np.array([10, 100, 20])
        upper_brown1 = np.array([20, 255, 200])
        lower_brown2 = np.array([20, 100, 20])
        upper_brown2 = np.array([30, 255, 200])

        brown_mask1 = cv2.inRange(hsv, lower_brown1, upper_brown1)
        brown_mask2 = cv2.inRange(hsv, lower_brown2, upper_brown2)
        brown_mask = brown_mask1 + brown_mask2

        brown_pixels = cv2.countNonZero(brown_mask)
        total_pixels = cv2.countNonZero(mask)

        if total_pixels > 0:
            brown_ratio = (brown_pixels / total_pixels) * 100
            if brown_ratio > 5:  # threshold (tweak this)
                print(f"Defected plant : p1{plants[i]}" )
                


detect_defected_plants("C:\\image1st\\New folder\\block1_image.jpg")
detect_defected_plants("C:\\image1st\\New folder\\block2_image.jpg")
#print(f"Defected plant in Block 1 : {block1}")
#print(f"Defected plant in Block 2 : {block2}")

# %%
import cv2
import numpy as np

import cv2
import numpy as np

image = cv2.imread("C:\\image1st\\New folder\\block1_sharper.jpg")
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

filtered_contours = []
for c in contours:
    area = cv2.contourArea(c)
    if 1000 < area < 80000:  # adjust these values as needed
        filtered_contours.append(c)

sorted_contours = sorted(filtered_contours, key=cv2.contourArea, reverse=True)

plants = ['A', 'B', 'C', 'D', 'E', 'F']
defected_plants = []

for i, cont in enumerate(sorted_contours[:len(plants)]):
    cv2.drawContours(image, [cont], -1, (0, 255, 0), 3)
    X, Y = cont[0][0]
    cv2.putText(image, "p1" + plants[i], (X, Y + 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)

    #creat mask  for this plant region
    mask = np.zeros_like(gray)
    cv2.drawContours(mask, [cont],  -1, 255, -1)

    #crop plant area
    plant_region = cv2.bitwise_and(image,image,mask=mask)
    hsv=cv2.cvtColor(plant_region,cv2.COLOR_BGR2HSV)



    lower_brown1 = np.array([10, 100, 20])
    upper_brown1 = np.array([20, 255, 200])
    lower_brown2 = np.array([20, 100, 20])
    upper_brown2 = np.array([30, 255, 200])

    brown_mask1 = cv2.inRange(hsv, lower_brown1, upper_brown1)
    brown_mask2= cv2.inRange(hsv,lower_brown2, upper_brown2)
    brown_mask = brown_mask1 + brown_mask2

    brown_pixels = cv2.countNonZero(brown_mask)
    total_pixels = cv2.countNonZero(mask)

    if total_pixels > 0:
        brown_ratio = (brown_pixels / total_pixels) * 100
        if brown_ratio > 5:  # threshold (tweak this)
            defected_plants.append(plants[i])


print(f"defected plant : P1{defected_plants}")
cv2.imshow("contour image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
print(f"defected plant : P1{defected_plants}")
cv2.imshow("contour image", image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# defected plant : P1['C']

# %%
def plants():
   
    image = cv2.imread("C:\\image1st\\New folder\\block1_sharper.jpg")
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    ret, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)
    
    contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)
    
    filtered_contours = []
    for c in contours:
        area = cv2.contourArea(c)
        if 1000 < area < 80000:  # adjust these values as needed
            filtered_contours.append(c)
    
    sorted_contours = sorted(filtered_contours, key=cv2.contourArea, reverse=True)
    
    plants = ['A', 'B', 'C', 'D', 'E', 'F']
    defected_plants = []
    
    for i, cont in enumerate(sorted_contours[:len(plants)]):
        cv2.drawContours(image, [cont], -1, (0, 255, 0), 3)
        X, Y = cont[0][0]
        cv2.putText(image, "p1" + plants[i], (X, Y + 60), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 0, 255), 2)
    
        #creat mask  for this plant region
        mask = np.zeros_like(gray)
        cv2.drawContours(mask, [cont],  -1, 255, -1)
    
        #crop plant area
        plant_region = cv2.bitwise_and(image,image,mask=mask)
        hsv=cv2.cvtColor(plant_region,cv2.COLOR_BGR2HSV)
    
    
    
        lower_brown1 = np.array([10, 100, 20])
        upper_brown1 = np.array([20, 255, 200])
        lower_brown2 = np.array([20, 100, 20])
        upper_brown2 = np.array([30, 255, 200])
    
        brown_mask1 = cv2.inRange(hsv, lower_brown1, upper_brown1)
        brown_mask2= cv2.inRange(hsv,lower_brown2, upper_brown2)
        brown_mask = brown_mask1 + brown_mask2
    
        brown_pixels = cv2.countNonZero(brown_mask)
        total_pixels = cv2.countNonZero(mask)
    
        if total_pixels > 0:
            brown_ratio = (brown_pixels / total_pixels) * 100
            if brown_ratio > 5:  # threshold (tweak this)
                defected_plants.append(plants[i])
    
    
    print(f"defected plant : P1{defected_plants}")
    cv2.imshow("contour image", image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
