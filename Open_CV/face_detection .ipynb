# %%
import cv2

# %%
face_cascade=cv2.CascadeClassifier("pen_CV/haarcascade_frontalface_alt.xml")

cap=cv2.VideoCapture(0)
while True:
    ret, frame=cap.read()
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    face=face_cascade.detectmultiscale(gray,1.1,5)
    """
2. .detectMultiScale()

This function scans the image (gray in this case) and tries to find objects (faces).
It returns a list of rectangles, each rectangle representing a detected face:
(x, y, w, h)
(x, y) → top-left corner of face
w → width
h → height
    """
    for (x,y,w,h)in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,255,0),2)

        """
        x,y = top left corner
        faces = [
        (100,150,80,80) face1
        (250,120,90,90) face2
        ]
        x = how far from face1
        y = how far from face2
        w = width of face
        h = height of face
        """
    cv2.imshow("webcam Face Detection",frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 7
#       5     ret, frame=cap.read()
#       6     gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
# ----> 7     faces=face_cascade.detectmultiscale(gray,1.1,5)
#       8     """
#       9 2. .detectMultiScale()
#      10
#    (...)
#      16 h → height
#      17     """
#      18     for (x,y,w,h)in faces:
#
# AttributeError: 'cv2.CascadeClassifier' object has no attribute 'detectmultiscale'
