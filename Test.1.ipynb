# %%
#ques 
name=input("enter name")
dic={"Alice":"HR","Bob":"TT","Charliae":"Finance"}
if name in dic:
    
print(dic['Alice'])
# Out:
# HR

# %%
# ques 2
n=5
for i in range(1,11):
    print(n,"x",i,"=",n*i)
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
#quees 3
email = ['email1@gmail.com.com', 'email2@outlook.com']
l=len(email)
for i in range(l):
    new=email[i]
    for j in range(len(new)):
        if new[j]=="@":
            p=j+1
            s=new[p:len(new)]
            print(s)
# Out:
# gmail.com.com
# outlook.com

# %%
#ques 4
sen=("Write a Python function to find the largest word")
s=sen.split()
print(max(s,key=len))
# Out:
# function

# %%
#ques 6
no = ['(123) 456-7890', '(123-456-7890', '(987) 654-3210']
l=len(no)
for i in range(l):
    new=no[i]
    for j in range(len(new)):
        if new[0]=="(" and new[4]==")" and new[5]==" " and new[9]=="-": 
            print(new)
            break
# Out:
# (123) 456-7890
# (987) 654-3210

# %%
#ques 7
user=input("enter product name :")
product =  [{"name": "Product1", "price": 10.5}, {"name": "Product2", "price": 15.0}]
if user="Product1":
    print(product)
# Out:
# enter product name : Product1

# %%
#ques 8
class info:
    def information(self,idno,dep,sal):
    
        self.idno=idno
        self.dep=dep
        self.sal=sal
    
    def show(self):
        annual=self.sal*12
        print("Annual Income :",annual)
        print("Employee_id :", self.idno)
        print("Department  :", self.dep)
        print("Salary      :", self.sal)
        update=int(input("you want to update write (0,1) :"))
        if update==1:
            self.dep=input("change")
            print("D
        
a1=info()
a1.information("Jiya","AIML",574567)
print(a1.show())
# Out:
# Annual Income : 6894804
# Employee_id : Jiya
# Department  : AIML
# Salary      : 574567
# None

# %%
# QUES 9
n="hello"
print(n[4::-1])
# Out:
# olleh

# %%
# QUES 10
I=input("enter")
freq={}
count=1
for i in range(len(I)):
    if I[i] in freq:
        count+=1
        freq[I[i]]=count
    else:
        count=1
        freq[I[i]]=count
print(freq)
# Out:
# enter Assessment
# {'A': 1, 's': 4, 'e': 5, 'm': 4, 'n': 5, 't': 5}
