# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# line plot
x=[2,4,6,8,10]
y=[3,3,2,7,9]
plt.plot(x,y)
plt.show()

# %%
df={
    'name': ['jiya', 'sandhya', 'aaditya', 'jeet'],
 'age': [18, 19, 20, 19],
 'height': [5.3, 5.4, 5.8, 5.5]
}
df
# Out:
# {'name': ['jiya', 'sandhya', 'aaditya', 'jeet'],
#  'age': [18, 19, 20, 19],
#  'height': [5.3, 5.4, 5.8, 5.5]}

# %%
fruit=pd.read_csv("C:\\Users\\jiyad\\OneDrive\\Desktop\\fruit1.csv")
fruit
# Out:
#           FRUIT     MONTH  SALES SALESMAN  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0        Banana   January     34      BOB         NaN         NaN         NaN
# 1         Apple  February     45      DOT         NaN         NaN         NaN
# 2          Pear     March   2000      SUE         NaN         NaN         NaN
# 3          Kiwi     April     76     MARY         NaN         NaN         NaN
# 4    Strawberry       May     87      DOT         NaN         NaN         NaN
# ..          ...       ...    ...      ...         ...         ...         ...
# 289  Strawberry  February      4      DOT         NaN         NaN         NaN
# 290      Banana     March      8      SUE         NaN         NaN         NaN
# 291       Apple     April      6    ALICE         NaN         NaN         NaN
# 292        Pear       May      9      DOT         NaN         NaN         NaN
# 293        Kiwi      June     76      SUE         NaN         NaN         NaN
#
# ...

# %%
fruit.plot()
# Out:
# <Axes: >

# %%
fruit.plot(kind="bar")
# Out:
# <Axes: >

# %%
#graph attibute
plt.xlabel("show x side of the graph")
plt.ylabel("show y side of the graph")
# Out:
# Text(0, 0.5, 'show y side of the graph')

# %%
plt.legend()
# Out:
# C:\Users\jiyad\AppData\Local\Temp\ipykernel_23300\4061938096.py:1: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
# histrogram chart
plt.hist(df["age"])

# %% [markdown]
# # key plotting function

# %%
# line plot
plt.plot(x,y)

# %%
# scatter plot
plt.scatter(x,y)
plt.grid(True)

# %%
#bar chart
plt.bar(x,y)
# Out:
# <BarContainer object of 5 artists>

# %%
# historam
plt.hist(df["age"])
# Out:
# (array([1., 0., 0., 0., 0., 2., 0., 0., 0., 1.]),
#  array([18. , 18.2, 18.4, 18.6, 18.8, 19. , 19.2, 19.4, 19.6, 19.8, 20. ]),
#  <BarContainer object of 10 artists>)

# %%
# pie chart
plt.pie(x)
plt.grid()
plt.show()

# %%
# box plot
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2a8cd086990>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2a8cd086c10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2a8cd086850>],
#  'medians': [<matplotlib.lines.Line2D at 0x2a8cd086e90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2a8cd086fd0>],
#  'means': []}

# %%
# customizing 
plt.plot(x,y,color="red",marker="*",linestyle="--")

# %%
plt.title("sales over time")
plt.xlabel("quarter")
plt.ylabel("sales in lakh")
plt.grid(True)
plt.show()

# %%
# subplots
plt.subplot(4,6,7)
# Out:
# <Axes: >

# %%
plt.plot([1,2,4],[9,8,7])

# %%
plt.bar([1,2,4],[9,8,7])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.show()
