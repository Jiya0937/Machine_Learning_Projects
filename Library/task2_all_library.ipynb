# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
arr=np.array([30000,90000,50000,100000,70000],)

# %%
df={
    "Depatment" : ["IT","AI","Cyber Crime","Data Science","Data Engineer"],
    "Salary" : [arr]
}

# %%
df
# Out:
# {'Depatment': ['IT', 'AI', 'Cyber Crime', 'Data Science', 'Data Engineer'],
#  'Salary': [array([ 30000,  90000,  50000, 100000,  70000])]}
