# %%
import keyword

# %%
#print keywords and reserved words
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a=46543
b=0b0101
c=0o756475
d=0x75543576af
print("DECIMAL : ",a,"BINARY :",b,"OCTALE :",c,"HEXADECIMAL :",d)
# Out:
# DECIMAL :  46543 BINARY : 5 OCTALE : 253245 HEXADECIMAL : 503923963567

# %%
a=1.2e3
print(a)
# Out:
# 1200.0

# %%
#complex number
a=0b1111+20j

print(a)
# Out:
# (15+20j)

# %%
b=20+0b1111j
b
# Out:
#   Cell In[8], line 1
#     b=20+0b1111j
#               ^
# SyntaxError: invalid binary literal

# %%
a=20+30j
print(a.real)
print(a.imag)
# Out:
# 20.0
# 30.0

# %%
a=True*True+True+True
a
# Out:
# 3

# %%
a=True+True # 1+1=2
b=False+False # 0+0=0
c=True+False #1+0=1
print(a,b,c)
# Out:
# 2 0 1

# %%
name="jiya"
lastname=" deshmukh"
print(name+lastname)
print(type(name))
# Out:
# jiya deshmukh
# <class 'str'>

# %%
a="jiya"
b="10"
print(a+b)
# Out:
# jiya10

# %%
a="riya"
print(a*3)
# Out:
# riyariyariya

# %%
#indexing
print(a[2])
# Out:
# y

# %%
#slicing
c="Acropolis"
print(c[0:4])
print(c[:])
print(c[:4])
print(c[-1::-1])
print(c[::2])
print(c[2::3])
h="hello"
print(h[-1::-1])
print(h[-1:-1]) # blank output
print(c[2::2])
print(c[::-1])
# Out:
# Acro
# Acropolis
# Acro
# siloporcA
# Arpls
# ros
# olleh
#
# rpls
# siloporcA

# %%
import numpy as np
a=np.array([[1,2,3],[2,4,6],[3,6,9]])
print(a)
# Out:
# [[1 2 3]
#  [2 4 6]
#  [3 6 9]]

# %%
print(a[0,2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 print(a[0,2])
#
# TypeError: 'int' object is not subscriptable

# %%
a=int(input("enter a : "))
b=int(input("enter b : "))
print("sum of a and b :",a+b)
# Out:
# enter a :  7
# enter b :  8
# sum of a and b : 15

# %%
#type conversion
#int
int(10.5)
int(True)
int("10")
str("jiya")
# Out:
# 'jiya'

# %%
#float
a=float(10)
b=float(True)
c=float("10")
d=float("10.5")
print(a,b,c,d)
# Out:
# 10.0 1.0 10.0 10.5

# %%
#complex
a=complex(67)
b=complex(33,44)
c=complex(10)
d=complex(10.5+6)
e=complex(True)
f=complex(False)
print(a,b,c,d,e,f)
# Out:
# (67+0j) (33+44j) (10+0j) (16.5+0j) (1+0j) 0j

# %%
#bool
a=bool(0)
n=bool(10)

m=bool(10+20j)
o=bool(0+0j)
j=bool(0+1j)
h=bool("jiiya")
print(a,n,m,o,j,h)
# Out:
# False True True False True True

# %%
#check string is palindrom or not
#average of three number
#simple interest

# %%
#a=int(input("enter number"))
a=212
add=0
rem=a%10
rev=a/10
add+=rem
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 3
#       1 #a=int(input("enter number"))
#       2 a=212
# ----> 3 b=a[::-1]
#       4 b
#
# TypeError: 'int' object is not subscriptable

# %%
#average of three number
a=int(input("enter a"))
b=int(input("enter b"))
c=int(input("enter c"))
add=a+b+c
ave=add/3
print(ave)
# Out:
# enter a 2
# enter b 4
# enter c 6
# 4.0

# %%
pri=int(input("enter principle"))
rate=int(input("enter rate"))
time=int(input("enter time"))
multi=pri*rate*time
simple_intereser=multi/100
print(simple_intereser)
# Out:
# enter principle 400
# enter rate 2
# enter time 1
# 8.0
