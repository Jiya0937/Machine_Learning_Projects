# %%
"""Problem 1: Loan EMI Calculator (math library)
 A bank officer needs to calculate the monthly EMI for a customer who takes a housing loan. Instead
 of manual calculations, the officer wants a program that calculates EMI based on loan amount,
 interest rate, and tenure.
 Example Input: Loan Amount = 5,00,000, Interest Rate = 7.5% per year, Tenure = 10 years
 Expected Output: EMI = 5,935.00 per month
 Hint: Use the EMI formula with math.pow()"""

# %%
import math as m

# %%
a=50
r=7
t=10
ans=m.prod(a,r)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 r=7
#       3 t=10
# ----> 4 ans=m.prod(a,r)
#
# TypeError: prod() takes exactly 1 positional argument (2 given)

# %%
#task 2
import statistics as st
data=[88,92,78,92,85,95,78,90,89]
mean=st.mean(data)
median=st.median(data)
mode=st.mode(data)
std=st.stdev(data)
print("Mean               : ",mean)
print("Mediun             : ",median)
print("Mode               : ",mode)
print("standerd Deviation : ",std)
# Out:
# Mean               :  87.44444444444444
# Mediun             :  89
# Mode               :  92
# standerd Deviation :  6.043821454822915

# %%
#task 3
import datetime as dt
st=dt.date(2025,8,1)

time=st-dt.timedelta(2025,8,25)
print(time)
# Out:
# 2020-01-15

# %%
#task 4
import collections as c
li=[]
rv="good product, very good quality, exellent product, good service"
split=rv.split()
print((c.Counter(split)))
# Out:
# Counter({'good': 3, 'product,': 2, 'very': 1, 'quality,': 1, 'exellent': 1, 'service': 1})

# %%
#task 5 
from collections import defaultdict 
d=c.defaultdict(list)

d["fruit"].append('apple')
d["fruit"].append('banana')
d['vegetables'].append('carrot')
d['stationary'].append('pen')
d
# Out:
# defaultdict(list,
#             {'fruit': ['apple', 'banana'],
#              'vegetables': ['carrot'],
#              'stationary': ['pen']})

# %%
#task 6
import datetime as dt
today=dt.datetime.now()
print(today)
left=dt.deltatime(2025,8,28)-today
left
# Out:
# 2025-08-26 08:37:53.924901
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 5
#       3 today=dt.datetime.now()
#       4 print(today)
# ----> 5 left=dt.deltatime(2025,8,28)-today
#       6 left
#
# AttributeError: module 'datetime' has no attribute 'deltatime'
