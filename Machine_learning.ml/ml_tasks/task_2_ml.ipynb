# %% [markdown]
# # ---------- By Linear Regression -----------
# # Predict Scores of Student Accouding to Their Academic Perfomance and Sleep Hours

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# %%
data = pd.read_csv("C:\\Users\\jiyad\\OneDrive\\Documents\\Desktop\\task_2_ml_ds.csv")
data
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %%
data.isnull().sum()
# Out:
# student_id            0
# hours_studied         0
# sleep_hours           0
# attendance_percent    0
# previous_scores       0
# exam_score            0
# dtype: int64

# %%
df = data.copy()
df
# Out:
#     student_id  hours_studied  sleep_hours  attendance_percent  \
# 0         S001            8.0          8.8                72.1
# 1         S002            1.3          8.6                60.7
# 2         S003            4.0          8.2                73.7
# 3         S004            3.5          4.8                95.1
# 4         S005            9.1          6.4                89.8
# ..         ...            ...          ...                 ...
# 195       S196           10.5          5.4                94.0
# 196       S197            7.1          6.1                85.1
# 197       S198            1.6          6.9                63.8
# 198       S199           12.0          7.3                50.5
# 199       S200           10.2          6.3                97.4
#
#      previous_scores  exam_score
# 0                 45        30.2
# 1                 55        25.0
# 2                 86        35.8
# 3                 66        34.0
# 4                 71        40.3
# ...

# %%
from sklearn.model_selection import train_test_split

X = df[['hours_studied', 'sleep_hours', 'attendance_percent', 'previous_scores']]
y = df[['exam_score']]

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size = 0.2 , random_state=2)

print("===Traning Data===\nschool perfomance")
print(X_train)

print("\n----Testing Data----\nschool perfomance")
print(X_test)

print("\n===Traning Data===\nExam Scores")
print(y_train)

print("\n----Testing Data----\nExam Scores")
print(y_test)
# Out:
# ===Traning Data===
# school perfomance
#      hours_studied  sleep_hours  attendance_percent  previous_scores
# 137            9.4          8.1                80.4               43
# 163           11.0          6.6                67.1               58
# 111            3.9          5.1                66.3               91
# 123            6.8          8.4                89.1               79
# 109           11.5          8.3                69.0               49
# ..             ...          ...                 ...              ...
# 43             4.2          8.7                97.5               52
# 22             4.7          6.7                59.7               59
# 72            10.6          7.3                70.8               74
# 15             7.0          9.0                51.2               41
# 168            3.4          4.0                81.8               69
#
# [160 rows x 4 columns]
#
# ----Testing Data----
# school perfomance
# ...

# %%
print("===Traning Data===\nschool perfomance")
X_train
# Out:
# ===Traning Data===
# school perfomance
#      hours_studied  sleep_hours  attendance_percent  previous_scores
# 137            9.4          8.1                80.4               43
# 163           11.0          6.6                67.1               58
# 111            3.9          5.1                66.3               91
# 123            6.8          8.4                89.1               79
# 109           11.5          8.3                69.0               49
# ..             ...          ...                 ...              ...
# 43             4.2          8.7                97.5               52
# 22             4.7          6.7                59.7               59
# 72            10.6          7.3                70.8               74
# 15             7.0          9.0                51.2               41
# 168            3.4          4.0                81.8               69
#
# [160 rows x 4 columns]

# %%
print("\n----Testing Data----\nschool perfomance")
X_test
# Out:
# ----Testing Data----
# school perfomance
#      hours_studied  sleep_hours  attendance_percent  previous_scores
# 112            6.5          5.2                88.1               76
# 29             7.6          8.8                88.5               62
# 182           11.8          5.5                91.5               74
# 199           10.2          6.3                97.4               68
# 193           11.2          6.7                89.9               59
# 85             3.4          8.5                97.7               46
# 10             3.4          5.3                90.9               81
# 54             8.1          9.0                62.4               70
# 115           10.6          8.4                91.6               55
# 35             7.1          4.6                52.5               84
# 12             1.3          6.3                83.6               71
# 92             9.7          7.2                71.8               68
# ...

# %%
print("\n===Traning Data===\nExam Scores")
y_train
# Out:
# ===Traning Data===
# Exam Scores
#      exam_score
# 137        35.1
# 163        35.8
# 111        34.8
# 123        39.3
# 109        42.2
# ..          ...
# 43         30.3
# 22         29.6
# 72         41.9
# 15         34.1
# 168        32.1
#
# [160 rows x 1 columns]

# %%
print("\n----Testing Data----\nExam Scores")
y_test
# Out:
# ----Testing Data----
# Exam Scores
#      exam_score
# 112        34.6
# 29         36.2
# 182        44.1
# 199        37.8
# 193        46.7
# 85         26.5
# 10         29.3
# 54         34.4
# 115        46.4
# 35         32.0
# 12         31.2
# 92         37.5
# 13         30.2
# 126        26.8
# 174        44.8
# 2          35.8
# 44         26.1
# 3          34.0
# 113        26.4
# 14         41.1
# 23         35.9
# 25         30.0
# 6          37.9
# 134        30.6
# 165        30.1
# 173        40.9
# 45         31.8
# 65         36.7
# 48         41.2
# 122        44.1
# 178        35.0
# 64         39.5
# 9          24.7
# 57         38.2
# 78         26.5
# 71         47.9
# 128        36.1
# 176        30.7
# 131        28.8
# 53         46.4

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(X_test.shape)
# Out:
# (160, 4)
# (40, 4)
# (160, 1)
# (40, 4)

# %%
X_train.hist(figsize=(12,10),bins=30, color='skyblue', edgecolor='black')
# Out:
# array([[<Axes: title={'center': 'hours_studied'}>,
#         <Axes: title={'center': 'sleep_hours'}>],
#        [<Axes: title={'center': 'attendance_percent'}>,
#         <Axes: title={'center': 'previous_scores'}>]], dtype=object)

# %%
# Predict the Final Scores According to Academic Perfomance of Student 
X = X_train[['hours_studied', 'sleep_hours', 'attendance_percent' ,'previous_scores']]
y = y_train['exam_score']

model = LinearRegression()
model.fit(X,y)
prediction = model.predict(X)

# Find Errors between Actual Scores and Predicted Scores
mae = mean_absolute_error(y,prediction)
mse = mean_squared_error(y,prediction)
rmse = np.sqrt(mse)
r2 = r2_score(y,prediction)

print("Mean Absolute Error : " , round(mae,2))  # round remove large decimal value after point
print("Mean Squared Error : " , round(mse, 2))
print("Root Mean Squared Error : " , round(rmse, 2))
print("R^2 Score (Model Accuracy) : ", round(r2, 2)) # if it r^2  closer to 1 = Better

# histogram
plt.figure(figsize = (10, 6))  # size of the graph(height , length)
plt.hist(y_train["exam_score"], bins=30, color='skyblue', edgecolor='black')
plt.title("Distributionof Final Exam Scores")
plt.xlabel("Final Exam Score")
plt.ylabel("Number of Student")
plt.grid(True)  # background lines
plt.show()

# scatter + Regression line
plt.figure(figsize = (10,6))
plt.scatter(X["hours_studied"], y, color = 'blue', label = "Actual Scores")
plt.plot(X["hours_studied"],prediction, color = 'red', label = "Predicted Scores (Regression Line)")
plt.title("Model Prediction VS Actual Score")
plt.xlabel("Study Hours per Week")
plt.ylabel("Final Output")
plt.grid(True)
plt.show()

new_perfomance = X_test[['hours_studied', 'sleep_hours', 'attendance_percent' ,'previous_scores']]
new_score_prediction = model.predict(new_perfomance)


print("\n--------Prediction Output of Student For Exam Scores -----------")
df2 = pd.DataFrame(new_score_prediction)
df2
# Out:
# Mean Absolute Error :  2.24
# Mean Squared Error :  7.06
# Root Mean Squared Error :  2.66
# R^2 Score (Model Accuracy) :  0.85
# --------Prediction Output of Student For Exam Scores -----------
#             0
# 0   36.003512
# 1   38.813754
# 2   44.644447
# 3   42.452182
# 4   41.931871
# 5   29.888997
# 6   32.467194
# 7   38.480975
# 8   42.150537
# 9   33.985601
# 10  27.511516
# 11  39.809827
# 12  27.310843
# 13  28.623640
# 14  41.931711
# 15  35.439849
# 16  26.258584
# 17  29.754278
# 18  24.522352
# 19  41.772472
# 20  33.335197
# 21  29.655793
# 22  42.169784
# 23  28.491848
# 24  27.280455
# 25  46.854915
# 26  27.624549
# 27  36.309955
# 28  43.224670
# 29  45.856954
# 30  36.202913
# 31  39.331064
# 32  28.151209
# 33  38.725880
# 34  29.243655
# 35  44.521137
# 36  39.946545
# 37  30.189727
# 38  31.461038
# 39  44.027040
