# %%
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\jiyad\\OneDrive\\Documents\\Desktop\\Dataset for ML\\titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
import sys
print(sys.version)
# Out:
# 3.10.19 | packaged by Anaconda, Inc. | (main, Oct 21 2025, 16:41:31) [MSC v.1929 64 bit (AMD64)]

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file = 'output.html')
# Out:
# Summarize dataset:  41%|▍| 7/17 [00:00<00:00, 25.32it/s, Describe variable:
# Summarize dataset:  65%|▋| 11/17 [00:00<00:00, 20.27it/s, Describe variable
# 100%|██████████████████████████████████████| 12/12 [00:00<00:00, 96.58it/s]
# Summarize dataset: 100%|████████| 47/47 [00:08<00:00,  5.69it/s, Completed]
# Generate report structure: 100%|█████████████| 1/1 [00:14<00:00, 14.22s/it]
# Render HTML: 100%|███████████████████████████| 1/1 [00:00<00:00,  1.77it/s]
# Export report to file: 100%|█████████████████| 1/1 [00:00<00:00, 34.09it/s]

# %%
# !pip install ipywidgets
# Out:
# Collecting ipywidgets
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: comm>=0.1.3 in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipywidgets) (8.38.0)
# Requirement already satisfied: traitlets>=4.3.1 in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipywidgets) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets)
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets)
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: colorama in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.4.6)
# Requirement already satisfied: decorator in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (1.3.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from ipython>=6.1.0->ipywidgets) (4.15.0)
# Requirement already satisfied: wcwidth in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: executing>=1.2.0 in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in c:\users\jiyad\anaconda3\envs\ml_env\lib\site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/914.9 kB ? eta -:--:--
#    --------------------- ---------------- 524.3/914.9 kB 493.7 kB/s eta 0:00:01
#    --------------------- ---------------- 524.3/914.9 kB 493.7 kB/s eta 0:00:01
#    -------------------------------- ----- 786.4/914.9 kB 486.4 kB/s eta 0:00:01
#    ---------------------------------------- 914.9/914.9 kB 509.6 kB/s  0:00:01
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ---------------------------------------- 0.0/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    ---- ----------------------------------- 0.3/2.2 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.2 MB 524.3 kB/s eta 0:00:04
#    -------------- ------------------------- 0.8/2.2 MB 599.2 kB/s eta 0:00:03
#    -------------- ------------------------- 0.8/2.2 MB 599.2 kB/s eta 0:00:03
#    -------------- ------------------------- 0.8/2.2 MB 599.2 kB/s eta 0:00:03
#    ------------------- -------------------- 1.0/2.2 MB 592.2 kB/s eta 0:00:02
#    ------------------- -------------------- 1.0/2.2 MB 592.2 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.2 MB 578.7 kB/s eta 0:00:02
#    ----------------------- ---------------- 1.3/2.2 MB 578.7 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.6/2.2 MB 566.9 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.6/2.2 MB 566.9 kB/s eta 0:00:02
#    ---------------------------- ----------- 1.6/2.2 MB 566.9 kB/s eta 0:00:02
#    --------------------------------- ------ 1.8/2.2 MB 541.2 kB/s eta 0:00:01
#    --------------------------------- ------ 1.8/2.2 MB 541.2 kB/s eta 0:00:01
#    -------------------------------------- - 2.1/2.2 MB 551.4 kB/s eta 0:00:01
#    ---------------------------------------- 2.2/2.2 MB 562.8 kB/s  0:00:03
# Installing collected packages: widgetsnbextension, jupyterlab_widgets, ipywidgets
#
#    ------------- -------------------------- 1/3 [jupyterlab_widgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    -------------------------- ------------- 2/3 [ipywidgets]
#    ---------------------------------------- 3/3 [ipywidgets]
#
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 widgetsnbextension-4.0.15
