# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\\jiyad\\OneDrive\\Documents\\Desktop\\Dataset for ML\\Global_Superstore2.csv", encoding = 'latin1')

# %%
df
# Out:
#        Row ID         Order ID  Order Date   Ship Date       Ship Mode  \
# 0       32298   CA-2012-124891  31-07-2012  31-07-2012        Same Day
# 1       26341    IN-2013-77878  05-02-2013  07-02-2013    Second Class
# 2       25330    IN-2013-71249  17-10-2013  18-10-2013     First Class
# 3       13524  ES-2013-1579342  28-01-2013  30-01-2013     First Class
# 4       47221     SG-2013-4320  05-11-2013  06-11-2013        Same Day
# ...       ...              ...         ...         ...             ...
# 51285   29002    IN-2014-62366  19-06-2014  19-06-2014        Same Day
# 51286   35398   US-2014-102288  20-06-2014  24-06-2014  Standard Class
# 51287   40470   US-2013-155768  02-12-2013  02-12-2013        Same Day
# 51288    9596   MX-2012-140767  18-02-2012  22-02-2012  Standard Class
# 51289    6147   MX-2012-134460  22-05-2012  26-05-2012    Second Class
#
#       Customer ID     Customer Name      Segment           City  \
# ...

# %% [markdown]
# # Univariate Analysis

# %%
# 1. Univariate Analysis (Single Variable)

# Analyze one column at a time.

# Practice Questions:

# What is the distribution of sales/revenue?

# Which category appears most frequently?

# What is the average rating/price/sales value?

# How many missing values exist in each column?

# Which product/category occurs most often?

# What is the maximum and minimum value of sales or profit?

# How many unique cities/customers/products exist?

# Common plots:

# Histogram

# Countplot

# Boxplot

# Pie chart

# %%
plt.hist(df['Sales'])
# Out:
# (array([5.075e+04, 4.800e+02, 4.400e+01, 8.000e+00, 5.000e+00, 0.000e+00,
#         1.000e+00, 1.000e+00, 0.000e+00, 1.000e+00]),
#  array([4.44000000e-01, 2.26424760e+03, 4.52805120e+03, 6.79185480e+03,
#         9.05565840e+03, 1.13194620e+04, 1.35832656e+04, 1.58470692e+04,
#         1.81108728e+04, 2.03746764e+04, 2.26384800e+04]),
#  <BarContainer object of 10 artists>)

# %%
sns.countplot(x = 'Category', data = df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>

# %%
import seaborn as sns
sns.countplot(x='Category', data=df)
# Out:
# <Axes: xlabel='Category', ylabel='count'>
