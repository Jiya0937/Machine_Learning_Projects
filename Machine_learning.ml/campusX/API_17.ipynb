# %% [markdown]
# # API - Application Programming Interface

# %%
import requests
import pandas as pd

# %%
response = requests.get("https://api.themoviedb.org/3/movie/popular?api_key=359bd5d9715fa8c14c783d34eb70f850")

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg',
#   'genre_ids': [16, 35, 12, 10751, 9648],
#   'id': 1084242,
#   'original_language': 'en',
#   'original_title': 'Zootopia 2',
#   'overview': "After cracking the biggest case in Zootopia's history, rookie cops Judy Hopps and Nick Wilde find themselves on the twisting trail of a great mystery when Gary De'Snake arrives and turns the animal metropolis upside down. To crack the case, Judy and Nick must go undercover to unexpected new parts of town, where their growing partnership is tested like never before.",
#   'popularity': 376.1868,
#   'poster_path': '/oJ7g2CifqpStmoYQyaLQgEU32qO.jpg',
#   'release_date': '2025-11-26',
#   'title': 'Zootopia 2',
#   'video': False,
#   'vote_average': 7.6,
#   'vote_count': 1297},
#  {'adult': False,
#   'backdrop_path': '/tyjXlexbNZQ0ZT1KEJslQtBirqc.jpg',
#   'genre_ids': [12, 53, 878],
#   'id': 840464,
#   'original_language': 'en',
# ...

# %%
#particular colunms
pd.DataFrame(response.json()['results']).head(200)[['id', 'title', 'overview', 'popularity', 'vote_average', 'vote_count']]
# Out:
#          id                                           title  \
# 0   1084242                                      Zootopia 2
# 1    840464                          Greenland 2: Migration
# 2   1306368                                         The Rip
# 3   1043197                                      Dust Bunny
# 4   1168190                               The Wrecking Crew
# 5   1419406                               The Shadow's Edge
# 6   1326878                                       Strangers
# 7   1242898                              Predator: Badlands
# 8     83533                            Avatar: Fire and Ash
# 9   1234731                                        Anaconda
# 10   991494     The SpongeBob Movie: Search for SquarePants
# 11  1368166                                   The Housemaid
# 12  1242501                                         Icefall
# 13  1412598                                    Killer Whale
# 14   755898                               War of the Worlds
# ...

# %%
# all columns
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path                  genre_ids  \
# 0   False  /5h2EsPKNDdB3MAtOk9MB9Ycg9Rz.jpg  [16, 35, 12, 10751, 9648]
# 1   False  /tyjXlexbNZQ0ZT1KEJslQtBirqc.jpg              [12, 53, 878]
# 2   False  /3F2EXWF1thX0BdrVaKvnm6mAhqh.jpg               [28, 53, 80]
# 3   False  /AecGG1XVCmkk7fT10ko3FC0dLIP.jpg               [28, 14, 53]
# 4   False  /cz4vLJrmaV1zJlRYbxqtvLzeLWB.jpg         [28, 35, 80, 9648]
# 5   False  /4BtL2vvEufDXDP4u6xQjjQ1Y2aT.jpg           [28, 80, 18, 53]
# 6   False  /xGbNoh7aWmU81oYuxJoFI07Rz5I.jpg               [28, 53, 80]
# 7   False  /ebyxeBh56QNXxSJgTnmz7fXAlwk.jpg              [28, 878, 12]
# 8   False  /3Dqievkc7krcTtDE2hjRkIsEzB1.jpg              [878, 12, 14]
# 9   False  /swxhEJsAWms6X1fDZ4HdbvYBSf9.jpg               [12, 35, 27]
# 10  False  /gbjK8p5S1aLXWCwOoXqr9aWZvqG.jpg    [16, 10751, 35, 12, 14]
# 11  False  /sK3z0Naed3H1Wuh7a21YRVMxYqt.jpg                 [9648, 53]
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# for i in range(1, 555):
#     responserequests.get("https://api.themoviedb.org/3/movie/popularapi_key=359bd5d9715fa8c14c783d34eb70f850")
#     temp_df = pd.DataFra

# %%
for i in range(1,5):
    response = requests.get("https://api.themoviedb.org/3/movie/popular?api_key=359bd5d9715fa8c14c783d34eb70f850&page={i}")
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'popularity', 'vote_average', 'vote_count']]
    df.concat(df , temp_df, ignore_index= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[29], line 4
#       1 for i in range(1,5):
#       3     response = requests.get("https://api.themoviedb.org/3/movie/popular?api_key=359bd5d9715fa8c14c783d34eb70f850&page={i}")
# ----> 4     temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'popularity', 'vote_average', 'vote_count']]
#       5     df.concat(df , temp_df, ignore_index= True)
#
# KeyError: 'results'
