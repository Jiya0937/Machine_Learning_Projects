# %%
# EDA : Expoxitery data analysis
# univariant Analysis
# Bivarient Analysis
# Multivarient Analysis

# %%
# Data is in two types
# 1. numerical(age, marks, rant, battery) # in interger form
# 2. Categorical(gender, city, branch)#in string form

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("C:\\Users\\jiyad\\OneDrive\\Documents\\Desktop\\Dataset for ML\\titanic.csv")

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 116         1008         0       3              Thomas, Mr. John    male
# 134         1026         0       3        Dintcheff, Mr. Valtcho    male
# 142         1034         0       1    Ryerson, Mr. Arthur Larned    male
# 30           922         0       2  Louch, Mr. Charles Alexander    male
# 70           962         1       3     Mulvihill, Miss. Bertha E  female
#
#       Age  SibSp  Parch      Ticket      Fare            Cabin Embarked
# 116   NaN      0      0        2681    6.4375              NaN        C
# 134  43.0      0      0      349226    7.8958              NaN        S
# 142  61.0      1      3    PC 17608  262.3750  B57 B59 B63 B66        C
# 30   50.0      1      0  SC/AH 3085   26.0000              NaN        S
# 70   24.0      0      0      382653    7.7500              NaN        Q

# %% [markdown]
# # Categorical Data

# %% [markdown]
# # a. countplot

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df.shape
# Out:
# (418, 12)

# %%
df['Survived'].value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Pclass'].value_counts().plot(kind= 'bar')
df['Pclass'].value_counts()
# Out:
# Pclass
# 3    218
# 1    107
# 2     93
# Name: count, dtype: int64

# %%
sns.countplot(df['Sex'])
# Out:
# <Axes: xlabel='count', ylabel='Sex'>

# %%
sns.countplot(df['SibSp'])
# Out:
# <Axes: ylabel='count'>

# %%
df['SibSp'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='SibSp'>

# %% [markdown]
# # b. piechart

# %%
df['SibSp'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Sex'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind = 'pie', autopct = '%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical Data

# %% [markdown]
# # a. Histogram

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(df['Age'], bins = 5)
# Out:
# (array([ 32., 168.,  80.,  42.,  10.]),
#  array([ 0.17 , 15.336, 30.502, 45.668, 60.834, 76.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# #  b. Distplot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\jiyad\AppData\Local\Temp\ipykernel_21924\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# # c. Boxplot

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
df['Age'].min()
# Out:
# 0.17

# %%
df['Age'].max()
# Out:
# 76.0

# %%
df['Age'].mean()
# Out:
# np.float64(30.272590361445783)

# %%
df['Age'].skew()
# Out:
# np.float64(0.4573612871503845)
