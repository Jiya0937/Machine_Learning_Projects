# %%
import pickle
import numpy as np

# %%
with open('models/ohe_sex_embarked.pkl', 'rb') as f:
    ohe = pickle.load(f)

with open('models/clf.pkl', 'rb') as f:
    clf = pickle.load(f)

# %%
import os

print(os.path.getsize('models/ohe_sex_embarked.pkl'))
# Out:
# 656

# %%
# Assume user input
#pclass/gender/age/SibSp/Parch/fare/Embarked

test_input = np.array([3,	'female', 23.0,	0, 0, 8.6625, 'S'], dtype = object)

# %%
test_input
# Out:
# array([3, 'female', 23.0, 0, 0, 8.6625, 'S'], dtype=object)

# %%
# Remaining columns
remaining = test_input[[0,3,4,5]].reshape(1, -1)

# %%
test_input_sex_embarked = ohe.transform(np.array([[test_input[1],test_input[-1]]]))
# Out:
# C:\Users\jiyad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_age = np.array([[test_input[2]]])

# %%
test_input_transformed = np.concatenate((remaining, test_input_age, test_input_sex_embarked), 
                                       axis =1)

# %%
# Remaining columns
remaining = test_input[[0,3,4,5]].reshape(1, -1)

# Age
test_input_age = np.array([[test_input[2]]])

# Sex + Embarked together
test_input_sex_embarked = ohe.transform(
    [[test_input[1], test_input[-1]]]
)

# Concatenate
test_input_transformed = np.concatenate(
    (remaining, test_input_age, test_input_sex_embarked),
    axis=1
)
# Out:
# C:\Users\jiyad\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but OneHotEncoder was fitted with feature names
#   warnings.warn(

# %%
test_input_transformed.shape
# Out:
# (1, 10)

# %%
clf.predict(test_input_transformed)
# Out:
# array([1])
