# %%
import pandas as pd

# %%
pd.read_json("C:\\Users\\jiyad\\Downloads\\archive (11)\\train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
import pandas as pd

# %%
# !pip install mysql.connector
# Out:
# ...
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      ---------------------------------------- 0.0/11.9 MB ? eta -:--:--
#      - -------------------------------------- 0.5/11.9 MB 1.9 MB/s eta 0:00:06
#      --- ------------------------------------ 1.0/11.9 MB 2.2 MB/s eta 0:00:05
#      ----- ---------------------------------- 1.6/11.9 MB 2.4 MB/s eta 0:00:05
#      ------- -------------------------------- 2.1/11.9 MB 2.3 MB/s eta 0:00:05
#      ------- -------------------------------- 2.1/11.9 MB 2.3 MB/s eta 0:00:05
#      --------- ------------------------------ 2.9/11.9 MB 2.1 MB/s eta 0:00:05
#      ---------- ----------------------------- 3.1/11.9 MB 2.1 MB/s eta 0:00:05
#      ------------- -------------------------- 3.9/11.9 MB 2.2 MB/s eta 0:00:04
#      --------------- ------------------------ 4.7/11.9 MB 2.3 MB/s eta 0:00:04
#      ----------------- ---------------------- 5.2/11.9 MB 2.3 MB/s eta 0:00:03
# ...

# %%
import mysql.connector

# %%
conn = mysql.connector.connect(host='localhost', user = 'root', password = '', database = 'World')

# %%
pd.read_sql_query("SELECT * FROM city ", conn)
# Out:
# C:\Users\jiyad\AppData\Local\Temp\ipykernel_17196\3818667837.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city ", conn)
#         ID            Name CountryCode       District  Population
# 0        1           Kabul         AFG          Kabol     1780000
# 1        2        Qandahar         AFG       Qandahar      237500
# 2        3           Herat         AFG          Herat      186800
# 3        4  Mazar-e-Sharif         AFG          Balkh      127800
# 4        5       Amsterdam         NLD  Noord-Holland      731200
# ...    ...             ...         ...            ...         ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis      123175
# 4075  4076          Hebron         PSE         Hebron      119401
# ...

# %%
pd.read_sql_query("SELECT * FROM city WHERE District = 'Kabol' OR CountryCode = 'AFG'", conn)
# Out:
# C:\Users\jiyad\AppData\Local\Temp\ipykernel_17196\3798659095.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE District = 'Kabol' OR CountryCode = 'AFG'", conn)
#    ID            Name CountryCode  District  Population
# 0   1           Kabul         AFG     Kabol     1780000
# 1   2        Qandahar         AFG  Qandahar      237500
# 2   3           Herat         AFG     Herat      186800
# 3   4  Mazar-e-Sharif         AFG     Balkh      127800

# %%
pd.read_sql_query("SELECT * FROM city WHERE CountryCode Like 'IND'", conn)
# Out:
# C:\Users\jiyad\AppData\Local\Temp\ipykernel_17196\951274465.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM city WHERE CountryCode Like 'IND'", conn)
#        ID                Name CountryCode        District  Population
# 0    1024     Mumbai (Bombay)         IND     Maharashtra    10500000
# 1    1025               Delhi         IND           Delhi     7206704
# 2    1026  Calcutta [Kolkata]         IND    West Bengali     4399819
# 3    1027    Chennai (Madras)         IND      Tamil Nadu     3841396
# 4    1028           Hyderabad         IND  Andhra Pradesh     2964638
# ..    ...                 ...         ...             ...         ...
# 336  1360        Ambala Sadar         IND         Haryana       90712
# 337  1361          Baidyabati         IND    West Bengali       90601
# ...

# %%
pd.read_sql_query("SELECT * FROM country ", conn)
# Out:
# C:\Users\jiyad\AppData\Local\Temp\ipykernel_17196\35400287.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country ", conn)
#     Code          Name      Continent                     Region  SurfaceArea  \
# 0    ABW         Aruba  North America                  Caribbean        193.0
# 1    AFG   Afghanistan           Asia  Southern and Central Asia     652090.0
# 2    AGO        Angola         Africa             Central Africa    1246700.0
# 3    AIA      Anguilla  North America                  Caribbean         96.0
# 4    ALB       Albania         Europe            Southern Europe      28748.0
# ..   ...           ...            ...                        ...          ...
# 234  YEM         Yemen           Asia                Middle East     527968.0
# ...

# %%
pd.read_sql_query("SELECT * FROM country WHERE LocalName LIKE 'A%a' AND Code like 'A%'", conn)
# Out:
# C:\Users\jiyad\AppData\Local\Temp\ipykernel_17196\1109911641.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM country WHERE LocalName LIKE 'A%a' AND Code like 'A%'", conn)
#   Code                  Name      Continent                     Region  \
# 0  ABW                 Aruba  North America                  Caribbean
# 1  AGO                Angola         Africa             Central Africa
# 2  AIA              Anguilla  North America                  Caribbean
# 3  AND               Andorra         Europe            Southern Europe
# 4  ARE  United Arab Emirates           Asia                Middle East
# 5  ARG             Argentina  South America              South America
# 6  ASM        American Samoa        Oceania                  Polynesia
# ...

# %%
pd.read_sql_query("SELECT * FROM Countrylanguage ", conn)
# Out:
# C:\Users\jiyad\AppData\Local\Temp\ipykernel_17196\4103331087.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM Countrylanguage ", conn)
#     CountryCode    Language IsOfficial  Percentage
# 0           ABW       Dutch          T         5.3
# 1           ABW     English          F         9.5
# 2           ABW  Papiamento          F        76.7
# 3           ABW     Spanish          F         7.4
# 4           AFG     Balochi          F         0.9
# ..          ...         ...        ...         ...
# 979         ZMB      Tongan          F        11.0
# 980         ZWE     English          T         2.2
# 981         ZWE     Ndebele          F        16.2
# 982         ZWE      Nyanja          F         2.2
# 983         ZWE       Shona          F        72.1
#
# [984 rows x 4 columns]

# %%
pd.read_sql_query("SELECT * FROM Countrylanguage WHERE IsOfficial LIKE 'T'", conn)
# Out:
# C:\Users\jiyad\AppData\Local\Temp\ipykernel_17196\1185896715.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   pd.read_sql_query("SELECT * FROM Countrylanguage WHERE IsOfficial LIKE 'T'", conn)
#     CountryCode   Language IsOfficial  Percentage
# 0           ABW      Dutch          T         5.3
# 1           AFG       Dari          T        32.1
# 2           AFG     Pashto          T        52.4
# 3           AIA    English          T         0.0
# 4           ALB  Albaniana          T        97.9
# ..          ...        ...        ...         ...
# 233         ZAF  Afrikaans          T        14.3
# 234         ZAF    English          T         8.5
# 235         ZAF      Xhosa          T        17.7
# 236         ZAF       Zulu          T        22.7
# 237         ZWE    English          T         2.2
#
# ...

# %%
import mysql.connector

conn = mysql.connector.connect(
    host="localhost",
    user="root",
    password="Jiya@0937",
    database="MYSQL",
    port=3306
)

cursor = conn.cursor()
print("✅ MySQL connected successfully")
# Out:
# ✅ MySQL connected successfully
